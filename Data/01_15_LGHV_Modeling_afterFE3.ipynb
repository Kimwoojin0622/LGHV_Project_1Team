# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import scipy.stats as stats
import operator
import math
import warnings
import openpyxl
import random
warnings.filterwarnings('ignore')
from sklearn import tree
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, roc_auc_score, confusion_matrix, accuracy_score
import tensorflow as tf
from sklearn.utils import resample
from imblearn.over_sampling import SMOTE
from sklearn.utils import resample
from imblearn.under_sampling import TomekLinks
from imblearn.under_sampling import ClusterCentroids
from imblearn.under_sampling import CondensedNearestNeighbour
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
import pandas as pd

# 한글 글꼴체 변경
plt.rcParams['font.family'] ='Malgun Gothic'
# df.head() 이런거 했을 때, 컬럼이 생략되지 않고, 모든 컬럼 뜨게
pd.set_option('display.max_columns', None)
# 지수 표기법 대신에 소수점으로 표시하는코드
pd.options.display.float_format = '{:.2f}'.format
# 값 길이 제한 X
pd.set_option('display.max_colwidth', None) # 값 길이 제한 없음

# %% [markdown]
# 01_14_LGHV_Modeling_afterFE2.ipynb 에서의 모델링을 통해 나온 상위 7개 Features로 모델링 진행

# %% [markdown]
# #### ✅ 3차 선정된 Features

# %% [markdown]
# | Feature |
# |---------|
# | `TOTAL_USED_DAYS` |
# | `CH_LAST_DAYS_BF_GRP` |
# | `TV_I_CNT` |
# | `AGE_GRP10` |
# | `VOC_STOP_CANCEL_MONTH1_YN` |
# | `CH_HH_AVG_MONTH1` |
# | `MONTHS_REMAINING` |
#
# 해당 Feature들을 가지고 **모델링을 한 번 더 진행!!**

# %% [markdown]
# ---

# %%
df_real = pd.read_csv("data/full_data/TPS_cancel_data_FeatureEngineering_end.csv")

# %%
# 해당 컬럼들 들고오기

df = df_real.filter(items=['sha2_hash','TOTAL_USED_DAYS','TV_I_CNT','CH_LAST_DAYS_BF_GRP',
                           'VOC_STOP_CANCEL_MONTH1_YN','AGE_GRP10',
                 'CH_HH_AVG_MONTH1','MONTHS_REMAINING','p_mt','churn'])

# %%
df.columns
# Out:
# Index(['sha2_hash', 'TOTAL_USED_DAYS', 'TV_I_CNT', 'CH_LAST_DAYS_BF_GRP',
#        'VOC_STOP_CANCEL_MONTH1_YN', 'AGE_GRP10', 'CH_HH_AVG_MONTH1',
#        'MONTHS_REMAINING', 'p_mt', 'churn'],
#       dtype='object')

# %% [markdown]
# ---

# %% [markdown]
# ### 랜덤 언더 샘플링 데이터로 진행
# 1. 로지스틱
# 2. 랜덤 포레스트
# 3. XGB
# 4. LGBM
# 5. Cat

# %% [markdown]
# #### 1. LR 랜덤 언더 샘플링 데이터

# %%
# 2월 ~ 9월 train
# 6월 val
# 11월 test
train = df[df['p_mt'].isin([2,3,4,5,7,8,9])]
val = df[df['p_mt'] == 6]
test = df[df['p_mt'] == 11]

# %%
train
# Out:
#                                                                  sha2_hash  \
# 0         0000113b86db7c509bbe74d609529031b03b7c033dbdfbd8b7fcecbf92bc8600
# 1         0000113b86db7c509bbe74d609529031b03b7c033dbdfbd8b7fcecbf92bc8600
# 2         0000113b86db7c509bbe74d609529031b03b7c033dbdfbd8b7fcecbf92bc8600
# 3         0000113b86db7c509bbe74d609529031b03b7c033dbdfbd8b7fcecbf92bc8600
# 5         0000113b86db7c509bbe74d609529031b03b7c033dbdfbd8b7fcecbf92bc8600
# ...                                                                    ...
# 21483370  fffffa7eda8144ce27e65690933ae8994e6962fefd24c982990467add99d61a7
# 21483371  fffffa7eda8144ce27e65690933ae8994e6962fefd24c982990467add99d61a7
# 21483373  fffffa7eda8144ce27e65690933ae8994e6962fefd24c982990467add99d61a7
# 21483374  fffffa7eda8144ce27e65690933ae8994e6962fefd24c982990467add99d61a7
# 21483375  fffffa7eda8144ce27e65690933ae8994e6962fefd24c982990467add99d61a7
#
#           TOTAL_USED_DAYS  TV_I_CNT CH_LAST_DAYS_BF_GRP  \
# 0                     733      3.00              3개월내없음
# 1                     764      3.00                일주일내
# 2                     794      3.00                3주일전
# 3                     825      3.00                4주일전
# 5                     886      3.00                일주일내
# ...                   ...       ...                 ...
# 21483370             2215      1.00                일주일내
# 21483371             2246      1.00                일주일내
# 21483373             2307      1.00                일주일내
# 21483374             2338      1.00                일주일내
# 21483375             2368      1.00                일주일내
#
#          VOC_STOP_CANCEL_MONTH1_YN AGE_GRP10  CH_HH_AVG_MONTH1  \
# 0                                N       60대              0.00
# 1                                N       60대              6.72
# 2                                N       60대              9.86
# 3                                N       60대              5.95
# 5                                N       60대              2.93
# ...                            ...       ...               ...
# 21483370                         N       50대              2.42
# 21483371                         N       50대              3.67
# 21483373                         N       50대              4.10
# 21483374                         N       50대              2.03
# 21483375                         N       50대              2.91
#
#           MONTHS_REMAINING  p_mt churn
# 0                       13     2     N
# 1                       12     3     N
# 2                       11     4     N
# 3                       10     5     N
# 5                        8     7     N
# ...                    ...   ...   ...
# 21483370               -36     4     N
# 21483371               -37     5     N
# 21483373               -39     7     N
# 21483374               -40     8     N
# 21483375               -41     9     N
#
# [13691921 rows x 10 columns]

# %%
train = train.drop(columns=['sha2_hash','p_mt'])
val = val.drop(columns=['sha2_hash','p_mt'])
test = test.drop(columns=['sha2_hash','p_mt'])

# %%
from imblearn.under_sampling import RandomUnderSampler

X = train.drop(columns = ['churn'])
y = train['churn']

rus = RandomUnderSampler(random_state=42)
X_resampled, y_resampled = rus.fit_resample(X, y)

# %%
print("Before RU:")
print(y.value_counts())

print("\nAfter RU:")
print(pd.Series(y_resampled).value_counts())
# Out:
# Before RU:
# churn
# N    13599467
# Y       92454
# Name: count, dtype: int64
#
# After RU:
# churn
# N    92454
# Y    92454
# Name: count, dtype: int64

# %%
X_resampled = pd.DataFrame(X_resampled, columns=X.columns)
y_resampled = pd.Series(y_resampled, name='churn')

resampled_data = pd.concat([X_resampled, y_resampled], axis=1)

# %%
train = resampled_data

# %%
categorical_cols = train.select_dtypes(include=['object']).columns

# Train에는 없고 Validation에만 있는 값 찾기
unseen_values = {}

for col in categorical_cols:
    train_unique = set(train[col].unique())
    val_unique = set(val[col].unique())

    unseen = val_unique - train_unique
    if unseen:
        unseen_values[col] = unseen

# 결과 출력
print(unseen_values)
# Out:
# {}

# %%
# 레이블 인코딩 진행!

from sklearn.preprocessing import LabelEncoder

categorical_cols = train.select_dtypes(include=['object']).columns

# 레이블 인코딩 수행
label_encoders = {}
for col in categorical_cols:
    le = LabelEncoder()
    train[col] = le.fit_transform(train[col])
    val[col] = le.transform(val[col])
    test[col] = le.transform(test[col])
    label_encoders[col] = le

print("레이블 인코딩 끝")
# Out:
# 레이블 인코딩 끝

# %%
display(train)
display(val)
display(test)
# Out:
#         TOTAL_USED_DAYS  TV_I_CNT  CH_LAST_DAYS_BF_GRP  \
# 0                  2926      2.00                    3
# 1                  3631      2.00                    1
# 2                  1728      3.00                    4
# 3                  1825      2.00                    4
# 4                  1610      3.00                    4
# ...                 ...       ...                  ...
# 184903             3712      2.00                    4
# 184904              501      2.00                    1
# 184905               11      2.00                    4
# 184906              231      1.00                    5
# 184907              370      2.00                    4
#
#         VOC_STOP_CANCEL_MONTH1_YN  AGE_GRP10  CH_HH_AVG_MONTH1  \
# 0                               0          5              0.01
# 1                               0          5              0.00
# 2                               0          4              6.11
# 3                               0          3              0.91
# 4                               0          3              6.28
# ...                           ...        ...               ...
# 184903                          0          5              1.90
# 184904                          0          2              0.00
# 184905                          0          4              3.49
# 184906                          0          4              0.62
# 184907                          0          3              0.46
#
#         MONTHS_REMAINING  churn
# 0                    -23      0
# 1                     10      0
# 2                     16      0
# 3                      8      0
# 4                     20      0
# ...                  ...    ...
# 184903                30      1
# 184904                20      1
# 184905                36      1
# 184906                29      1
# 184907                36      1
#
# [184908 rows x 8 columns]
#           TOTAL_USED_DAYS  TV_I_CNT  CH_LAST_DAYS_BF_GRP  \
# 4                     855      3.00                    4
# 15                   4249      2.00                    4
# 26                   2488      6.00                    4
# 37                   1836      3.00                    4
# 48                   3826      4.00                    4
# ...                   ...       ...                  ...
# 21483328             3446      2.00                    0
# 21483339             2128      3.00                    4
# 21483350             3805      2.00                    4
# 21483361             1399      2.00                    4
# 21483372             2276      1.00                    4
#
#           VOC_STOP_CANCEL_MONTH1_YN  AGE_GRP10  CH_HH_AVG_MONTH1  \
# 4                                 0          5              4.03
# 15                                0          4             18.08
# 26                                0          5              1.09
# 37                                0          5              1.32
# 48                                0          4              1.27
# ...                             ...        ...               ...
# 21483328                          0          4              1.72
# 21483339                          0          3              2.12
# 21483350                          0          2              0.73
# 21483361                          0          4              4.37
# 21483372                          0          4              3.14
#
#           MONTHS_REMAINING  churn
# 4                        9      0
# 15                      12      0
# 26                      25      0
# 37                      -5      0
# 48                     -46      0
# ...                    ...    ...
# 21483328               -43      0
# 21483339               -34      0
# 21483350              -104      0
# 21483361                24      0
# 21483372               -38      0
#
# [1955115 rows x 8 columns]
#           TOTAL_USED_DAYS  TV_I_CNT  CH_LAST_DAYS_BF_GRP  \
# 9                    1008      3.00                    4
# 20                   4402      2.00                    4
# 31                   2641      6.00                    4
# 42                   1989      3.00                    4
# 53                   3979      4.00                    4
# ...                   ...       ...                  ...
# 21483333             3599      2.00                    1
# 21483344             2281      3.00                    4
# 21483355             3958      2.00                    4
# 21483366             1552      2.00                    4
# 21483377             2429      1.00                    1
#
#           VOC_STOP_CANCEL_MONTH1_YN  AGE_GRP10  CH_HH_AVG_MONTH1  \
# 9                                 0          5              6.23
# 20                                0          4             15.37
# 31                                0          5              1.47
# 42                                0          5              2.16
# 53                                0          4              1.64
# ...                             ...        ...               ...
# 21483333                          0          4              0.00
# 21483344                          0          3              1.81
# 21483355                          0          2              1.69
# 21483366                          0          4              3.39
# 21483377                          0          4              0.00
#
#           MONTHS_REMAINING  churn
# 9                       33      0
# 20                       7      0
# 31                      20      0
# 42                     -10      0
# 53                     -51      0
# ...                    ...    ...
# 21483333               -48      0
# 21483344               -39      0
# 21483355              -109      0
# 21483366                19      0
# 21483377               -43      0
#
# [1945592 rows x 8 columns]

# %%
from sklearn.preprocessing import MinMaxScaler, RobustScaler

# 내가 정한 robust 스케일링 컬럼들
robust_columns = ['TOTAL_USED_DAYS', 'CH_HH_AVG_MONTH1','MONTHS_REMAINING']  # RobustScaler를 적용할 컬럼
minmax_columns = [col for col in train.columns if col not in robust_columns + ['churn']]  # 나머지 컬럼

# 스케일러 생성
robust_scaler = RobustScaler()
minmax_scaler = MinMaxScaler()

# RobustScaler 적용
train[robust_columns] = robust_scaler.fit_transform(train[robust_columns])
val[robust_columns] = robust_scaler.transform(val[robust_columns])
test[robust_columns] = robust_scaler.transform(test[robust_columns])

# MinMaxScaler 적용
train[minmax_columns] = minmax_scaler.fit_transform(train[minmax_columns])
val[minmax_columns] = minmax_scaler.transform(val[minmax_columns])
test[minmax_columns] = minmax_scaler.transform(test[minmax_columns])

# 결과 확인
print("robust, minmax 끝")
# Out:
# robust, minmax 끝

# %%
# 로지스틱 회귀 모델 진행

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

X_train = train.drop(columns=['churn'])
y_train = train['churn']

# 로지스틱 회귀 모델 생성
#
model = LogisticRegression(solver='liblinear', random_state=42)

# 모델 학습
model.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=42, solver='liblinear')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score, roc_curve
from sklearn.metrics import ConfusionMatrixDisplay  # ConfusionMatrixDisplay 임포트
import matplotlib.pyplot as plt
import seaborn as sns

# Seaborn 스타일 초기화
sns.set_style("white")

# 검증 데이터
X_val = val.drop(columns=['churn'])
y_val = val['churn']

# -----------------------------------------------------------
# 검증 데이터 (Validation) 평가
# -----------------------------------------------------------
# 검증 데이터(val) 예측
val_predictions = model.predict(X_val)

# 정확도 확인
val_accuracy = accuracy_score(y_val, val_predictions)
print(f"Validation Accuracy: {val_accuracy:.2f}")

# Classification Report
print("\nClassification Report (Validation):")
print(classification_report(y_val, val_predictions))

# Confusion Matrix
print("\nConfusion Matrix (Validation):")
print(confusion_matrix(y_val, val_predictions))
disp_val = ConfusionMatrixDisplay(confusion_matrix=confusion_matrix(y_val, val_predictions), display_labels=model.classes_)

# Confusion Matrix
plt.figure()
disp_val.plot(cmap="Blues", ax=plt.gca())
plt.grid(False)
plt.title("Validation Confusion Matrix")
plt.show()

# AUC-ROC 계산 및 시각화
val_probabilities = model.predict_proba(X_val)[:, 1]  # 클래스 1에 대한 확률
val_auc = roc_auc_score(y_val, val_probabilities)
print(f"Validation AUC-ROC: {val_auc:.2f}")

# ROC Curve 시각화
fpr_val, tpr_val, thresholds_val = roc_curve(y_val, val_probabilities)
plt.figure()
plt.plot(fpr_val, tpr_val, label=f"Validation ROC Curve (AUC = {val_auc:.2f})")
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label="Random Guess")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Validation ROC Curve")
plt.legend()
plt.grid(False)
plt.show()
# Out:
# Validation Accuracy: 0.79
#
# Classification Report (Validation):
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88   1941863
#            1       0.02      0.63      0.04     13252
#
#     accuracy                           0.79   1955115
#    macro avg       0.51      0.71      0.46   1955115
# weighted avg       0.99      0.79      0.88   1955115
#
#
# Confusion Matrix (Validation):
# [[1535906  405957]
#  [   4933    8319]]
# Validation AUC-ROC: 0.77

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Feature Importance 추출 (절댓값 사용)
feature_importance = np.abs(model.coef_[0])

# DataFrame 변환 및 정렬
feature_importance_df = pd.DataFrame({
    'Feature': X_train.columns,
    'Importance': feature_importance
}).sort_values(by='Importance', ascending=False)

# Feature Importance 시각화
plt.figure(figsize=(10, 6))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'], color='skyblue')
plt.xlabel("Feature Importance")
plt.ylabel("Features")
plt.title("Logistic Regression Feature Importance")
plt.gca().invert_yaxis()
plt.show()

print("✅ Feature Importance")
for rank, feature in enumerate(feature_importance_df['Feature'], 1):
    print(f"{rank}. {feature}")
# Out:
# ✅ Feature Importance
# 1. VOC_STOP_CANCEL_MONTH1_YN
# 2. CH_LAST_DAYS_BF_GRP
# 3. AGE_GRP10
# 4. TOTAL_USED_DAYS
# 5. MONTHS_REMAINING
# 6. TV_I_CNT
# 7. CH_HH_AVG_MONTH1

# %% [markdown]
# ---

# %% [markdown]
# #### 2. 랜덤 포레스트 랜덤 언더 샘플링

# %%
X_train = train.drop(columns=['churn'])  # 독립 변수
y_train = train['churn']  # 종속 변수

# 랜덤 포레스트 모델
rf_model = RandomForestClassifier(
    n_estimators=100,  # 트리 개수
    random_state=42
)

# 모델 학습
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score, roc_curve
from sklearn.metrics import ConfusionMatrixDisplay  # ConfusionMatrixDisplay 임포트
import matplotlib.pyplot as plt
import seaborn as sns

# Seaborn 스타일 초기화
sns.set_style("white")

# 검증 데이터
X_val = val.drop(columns=['churn'])
y_val = val['churn']

# -----------------------------------------------------------
# 검증 데이터 (Validation) 평가
# -----------------------------------------------------------
# 검증 데이터(val) 예측
val_predictions = rf_model.predict(X_val)

# 정확도 확인
val_accuracy = accuracy_score(y_val, val_predictions)
print(f"Validation Accuracy: {val_accuracy:.2f}")

# Classification Report
print("\nClassification Report (Validation):")
print(classification_report(y_val, val_predictions))

# Confusion Matrix
print("\nConfusion Matrix (Validation):")
conf_matrix = confusion_matrix(y_val, val_predictions)
print(conf_matrix)
disp_val = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=rf_model.classes_)
disp_val.plot(cmap="Blues")
plt.title("Validation Confusion Matrix")
plt.show()

# -----------------------------------------------------------
# AUC-ROC 계산 및 시각화
# -----------------------------------------------------------
val_probabilities = rf_model.predict_proba(X_val)[:, 1]  # 클래스 1에 대한 확률
val_auc = roc_auc_score(y_val, val_probabilities)
print(f"Validation AUC-ROC: {val_auc:.2f}")

# ROC Curve 계산
fpr_val, tpr_val, thresholds_val = roc_curve(y_val, val_probabilities)

# ROC Curve 시각화
plt.figure()
plt.plot(fpr_val, tpr_val, label=f"Validation ROC Curve (AUC = {val_auc:.2f})", color='blue')
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label="Random Guess")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Validation ROC Curve")
plt.legend()
plt.grid(alpha=0.3)
plt.show()
# Out:
# Validation Accuracy: 0.77
#
# Classification Report (Validation):
#               precision    recall  f1-score   support
#
#            0       1.00      0.77      0.87   1941863
#            1       0.02      0.66      0.04     13252
#
#     accuracy                           0.77   1955115
#    macro avg       0.51      0.72      0.45   1955115
# weighted avg       0.99      0.77      0.87   1955115
#
#
# Confusion Matrix (Validation):
# [[1503651  438212]
#  [   4497    8755]]
# Validation AUC-ROC: 0.78

# %%
import pandas as pd
import matplotlib.pyplot as plt

feature_importance = rf_model.feature_importances_

feature_importance_df = pd.DataFrame({
    'Feature': X_train.columns,
    'Importance': feature_importance
}).sort_values(by='Importance', ascending=False)

plt.figure(figsize=(12, 8))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'], color='skyblue')
plt.xlabel("Feature Importance")
plt.ylabel("Features")
plt.title("Random Forest Feature Importance")
plt.gca().invert_yaxis()
plt.show()

print("✅ Feature Importance")
for rank, feature in enumerate(feature_importance_df['Feature'], 1):
    print(f"{rank}. {feature}")
# Out:
# ✅ Feature Importance
# 1. TOTAL_USED_DAYS
# 2. CH_HH_AVG_MONTH1
# 3. MONTHS_REMAINING
# 4. VOC_STOP_CANCEL_MONTH1_YN
# 5. CH_LAST_DAYS_BF_GRP
# 6. AGE_GRP10
# 7. TV_I_CNT

# %% [markdown]
# ---

# %% [markdown]
# #### 3. XGB 랜덤 언더 샘플링

# %%
from xgboost import XGBClassifier

# 독립 변수 & 종속 변수 설정
X_train = train.drop(columns=['churn'])  # 독립 변수
y_train = train['churn']  # 종속 변수

# XGBoost 모델 생성
xgb_model = XGBClassifier(
    n_estimators=100,
    max_depth=6,
    learning_rate=0.1,
    random_state=42
)

# 모델 학습
xgb_model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score, roc_curve
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import seaborn as sns

# Seaborn 스타일 초기화
sns.set_style("white")

# 검증 데이터
X_val = val.drop(columns=['churn'])
y_val = val['churn']

# -----------------------------------------------------------
# 검증 데이터 (Validation) 평가
# -----------------------------------------------------------
# 검증 데이터(val) 예측
val_predictions = xgb_model.predict(X_val)

# 정확도 확인
val_accuracy = accuracy_score(y_val, val_predictions)
print(f"Validation Accuracy: {val_accuracy:.2f}")

# Classification Report
print("\nClassification Report (Validation):")
print(classification_report(y_val, val_predictions))

# Confusion Matrix
print("\nConfusion Matrix (Validation):")
conf_matrix = confusion_matrix(y_val, val_predictions)
print(conf_matrix)
disp_val = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=xgb_model.classes_)
disp_val.plot(cmap="Blues")
plt.title("Validation Confusion Matrix")
plt.show()

# -----------------------------------------------------------
# AUC-ROC 계산 및 시각화
# -----------------------------------------------------------
val_probabilities = xgb_model.predict_proba(X_val)[:, 1]  # 클래스 1에 대한 확률
val_auc = roc_auc_score(y_val, val_probabilities)
print(f"Validation AUC-ROC: {val_auc:.2f}")

# ROC Curve 계산
fpr_val, tpr_val, thresholds_val = roc_curve(y_val, val_probabilities)

# ROC Curve 시각화
plt.figure()
plt.plot(fpr_val, tpr_val, label=f"Validation ROC Curve (AUC = {val_auc:.2f})", color='blue')
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label="Random Guess")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Validation ROC Curve")
plt.legend()
plt.grid(alpha=0.3)
plt.show()
# Out:
# Validation Accuracy: 0.81
#
# Classification Report (Validation):
#               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.90   1941863
#            1       0.02      0.68      0.05     13252
#
#     accuracy                           0.81   1955115
#    macro avg       0.51      0.75      0.47   1955115
# weighted avg       0.99      0.81      0.89   1955115
#
#
# Confusion Matrix (Validation):
# [[1577522  364341]
#  [   4230    9022]]
# Validation AUC-ROC: 0.82

# %%
import pandas as pd
import matplotlib.pyplot as plt

# XGBoost Feature Importance 추출
feature_importance = xgb_model.feature_importances_

# DataFrame 변환 및 정렬
feature_importance_df = pd.DataFrame({
    'Feature': X_train.columns,
    'Importance': feature_importance
}).sort_values(by='Importance', ascending=False)

# Feature Importance 시각화
plt.figure(figsize=(12, 8))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'], color='skyblue')
plt.xlabel("Feature Importance")
plt.ylabel("Features")
plt.title("XGBoost Feature Importance")
plt.gca().invert_yaxis()
plt.show()

print("✅ Feature Importance")
for rank, feature in enumerate(feature_importance_df['Feature'], 1):
    print(f"{rank}. {feature}")
# Out:
# ✅ Feature Importance
# 1. VOC_STOP_CANCEL_MONTH1_YN
# 2. CH_LAST_DAYS_BF_GRP
# 3. MONTHS_REMAINING
# 4. TOTAL_USED_DAYS
# 5. AGE_GRP10
# 6. TV_I_CNT
# 7. CH_HH_AVG_MONTH1

# %% [markdown]
# ---

# %% [markdown]
# #### 4. LGBM 랜덤 언더 샘플링

# %%
from lightgbm import LGBMClassifier

# 독립 변수 & 종속 변수 설정
X_train = train.drop(columns=['churn'])  # 독립 변수
y_train = train['churn']  # 종속 변수

# LightGBM 모델 생성
lgbm_model = LGBMClassifier(
    n_estimators=100,
    max_depth=-1,
    learning_rate=0.1,
    random_state=42 
)

# 모델 학습
lgbm_model.fit(X_train, y_train)
# Out:
# LGBMClassifier(random_state=42)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score, roc_curve
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import seaborn as sns

# Seaborn 스타일 초기화
sns.set_style("white")

# 검증 데이터
X_val = val.drop(columns=['churn'])
y_val = val['churn']

# -----------------------------------------------------------
# 검증 데이터 (Validation) 평가
# -----------------------------------------------------------
# 검증 데이터(val) 예측
val_predictions = lgbm_model.predict(X_val)

# 정확도 확인
val_accuracy = accuracy_score(y_val, val_predictions)
print(f"Validation Accuracy: {val_accuracy:.2f}")

# Classification Report
print("\nClassification Report (Validation):")
print(classification_report(y_val, val_predictions))

# Confusion Matrix
print("\nConfusion Matrix (Validation):")
conf_matrix = confusion_matrix(y_val, val_predictions)
print(conf_matrix)
disp_val = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=lgbm_model.classes_)
disp_val.plot(cmap="Blues")
plt.title("Validation Confusion Matrix")
plt.show()

# -----------------------------------------------------------
# AUC-ROC 계산 및 시각화
# -----------------------------------------------------------
val_probabilities = lgbm_model.predict_proba(X_val)[:, 1]  # 클래스 1에 대한 확률
val_auc = roc_auc_score(y_val, val_probabilities)
print(f"Validation AUC-ROC: {val_auc:.2f}")

# ROC Curve 계산
fpr_val, tpr_val, thresholds_val = roc_curve(y_val, val_probabilities)

# ROC Curve 시각화
plt.figure()
plt.plot(fpr_val, tpr_val, label=f"Validation ROC Curve (AUC = {val_auc:.2f})", color='blue')
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label="Random Guess")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Validation ROC Curve")
plt.legend()
plt.grid(alpha=0.3)
plt.show()
# Out:
# Validation Accuracy: 0.81
#
# Classification Report (Validation):
#               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.89   1941863
#            1       0.02      0.68      0.05     13252
#
#     accuracy                           0.81   1955115
#    macro avg       0.51      0.75      0.47   1955115
# weighted avg       0.99      0.81      0.89   1955115
#
#
# Confusion Matrix (Validation):
# [[1574882  366981]
#  [   4212    9040]]
# Validation AUC-ROC: 0.82

# %%
import pandas as pd
import matplotlib.pyplot as plt

# LightGBM Feature Importance 추출
feature_importance = lgbm_model.feature_importances_

# DataFrame 변환 및 정렬
feature_importance_df = pd.DataFrame({
    'Feature': X_train.columns,
    'Importance': feature_importance
}).sort_values(by='Importance', ascending=False)

# Feature Importance 시각화
plt.figure(figsize=(12, 8))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'], color='skyblue')
plt.xlabel("Feature Importance")
plt.ylabel("Features")
plt.title("LightGBM Feature Importance")
plt.gca().invert_yaxis()
plt.show()

print("✅ Feature Importance")
for rank, feature in enumerate(feature_importance_df['Feature'], 1):
    print(f"{rank}. {feature}")
# Out:
# ✅ Feature Importance
# 1. MONTHS_REMAINING
# 2. TOTAL_USED_DAYS
# 3. CH_HH_AVG_MONTH1
# 4. AGE_GRP10
# 5. CH_LAST_DAYS_BF_GRP
# 6. TV_I_CNT
# 7. VOC_STOP_CANCEL_MONTH1_YN

# %% [markdown]
# ---

# %% [markdown]
# #### 5. CatBoost 랜덤 언더 샘플링

# %%
from catboost import CatBoostClassifier

# 독립 변수 & 종속 변수 설정
X_train = train.drop(columns=['churn'])  # 독립 변수
y_train = train['churn']  # 종속 변수

# 기본값을 사용한 CatBoost 모델 생성
cat_model = CatBoostClassifier(
    iterations=1000,
    learning_rate=0.03,
    depth=6,
    random_seed=42
)

# 모델 학습
cat_model.fit(X_train, y_train)
# Out:
# 0:	learn: 0.6803947	total: 182ms	remaining: 3m 1s
# 1:	learn: 0.6683705	total: 201ms	remaining: 1m 40s
# 2:	learn: 0.6571258	total: 222ms	remaining: 1m 13s
# 3:	learn: 0.6468183	total: 245ms	remaining: 1m
# 4:	learn: 0.6376561	total: 267ms	remaining: 53.1s
# 5:	learn: 0.6289806	total: 287ms	remaining: 47.5s
# 6:	learn: 0.6210968	total: 312ms	remaining: 44.2s
# 7:	learn: 0.6140231	total: 342ms	remaining: 42.4s
# 8:	learn: 0.6074425	total: 370ms	remaining: 40.7s
# 9:	learn: 0.6011481	total: 389ms	remaining: 38.5s
# 10:	learn: 0.5954022	total: 413ms	remaining: 37.1s
# 11:	learn: 0.5901437	total: 437ms	remaining: 35.9s
# 12:	learn: 0.5852919	total: 460ms	remaining: 34.9s
# 13:	learn: 0.5809005	total: 478ms	remaining: 33.7s
# 14:	learn: 0.5768803	total: 508ms	remaining: 33.4s
# 15:	learn: 0.5731104	total: 537ms	remaining: 33s
# 16:	learn: 0.5694866	total: 562ms	remaining: 32.5s
# 17:	learn: 0.5660625	total: 581ms	remaining: 31.7s
# 18:	learn: 0.5629189	total: 612ms	remaining: 31.6s
# 19:	learn: 0.5599640	total: 644ms	remaining: 31.6s
# 20:	learn: 0.5572573	total: 668ms	remaining: 31.1s
# 21:	learn: 0.5547914	total: 688ms	remaining: 30.6s
# 22:	learn: 0.5524681	total: 710ms	remaining: 30.2s
# 23:	learn: 0.5504083	total: 735ms	remaining: 29.9s
# 24:	learn: 0.5484500	total: 756ms	remaining: 29.5s
# 25:	learn: 0.5465751	total: 783ms	remaining: 29.3s
# 26:	learn: 0.5447398	total: 812ms	remaining: 29.3s
# 27:	learn: 0.5430885	total: 842ms	remaining: 29.2s
# 28:	learn: 0.5416471	total: 862ms	remaining: 28.9s
# 29:	learn: 0.5401470	total: 889ms	remaining: 28.7s
# 30:	learn: 0.5387529	total: 919ms	remaining: 28.7s
# 31:	learn: 0.5375281	total: 945ms	remaining: 28.6s
# 32:	learn: 0.5364274	total: 962ms	remaining: 28.2s
# 33:	learn: 0.5353645	total: 992ms	remaining: 28.2s
# 34:	learn: 0.5342038	total: 1.02s	remaining: 28.2s
# 35:	learn: 0.5332289	total: 1.05s	remaining: 28.1s
# 36:	learn: 0.5322397	total: 1.07s	remaining: 27.9s
# 37:	learn: 0.5313796	total: 1.1s	remaining: 27.9s
# 38:	learn: 0.5304927	total: 1.13s	remaining: 28s
# 39:	learn: 0.5297470	total: 1.16s	remaining: 27.7s
# 40:	learn: 0.5290674	total: 1.18s	remaining: 27.7s
# 41:	learn: 0.5283794	total: 1.21s	remaining: 27.7s
# 42:	learn: 0.5276477	total: 1.24s	remaining: 27.6s
# 43:	learn: 0.5271111	total: 1.26s	remaining: 27.4s
# 44:	learn: 0.5264437	total: 1.29s	remaining: 27.4s
# 45:	learn: 0.5258369	total: 1.32s	remaining: 27.5s
# 46:	learn: 0.5253098	total: 1.35s	remaining: 27.3s
# 47:	learn: 0.5247857	total: 1.37s	remaining: 27.2s
# 48:	learn: 0.5243532	total: 1.4s	remaining: 27.2s
# 49:	learn: 0.5239505	total: 1.43s	remaining: 27.2s
# 50:	learn: 0.5235408	total: 1.45s	remaining: 27s
# 51:	learn: 0.5230665	total: 1.48s	remaining: 27s
# 52:	learn: 0.5226256	total: 1.51s	remaining: 27.1s
# 53:	learn: 0.5222417	total: 1.54s	remaining: 27s
# 54:	learn: 0.5219424	total: 1.56s	remaining: 26.8s
# 55:	learn: 0.5215884	total: 1.59s	remaining: 26.8s
# 56:	learn: 0.5212706	total: 1.62s	remaining: 26.8s
# 57:	learn: 0.5209890	total: 1.65s	remaining: 26.7s
# 58:	learn: 0.5207082	total: 1.67s	remaining: 26.6s
# 59:	learn: 0.5204801	total: 1.7s	remaining: 26.6s
# 60:	learn: 0.5202071	total: 1.73s	remaining: 26.7s
# 61:	learn: 0.5198963	total: 1.78s	remaining: 26.9s
# 62:	learn: 0.5196302	total: 1.81s	remaining: 27s
# 63:	learn: 0.5193697	total: 1.84s	remaining: 26.9s
# 64:	learn: 0.5191306	total: 1.86s	remaining: 26.7s
# 65:	learn: 0.5188089	total: 1.89s	remaining: 26.7s
# 66:	learn: 0.5186033	total: 1.92s	remaining: 26.8s
# 67:	learn: 0.5183391	total: 1.94s	remaining: 26.6s
# 68:	learn: 0.5181348	total: 1.96s	remaining: 26.5s
# 69:	learn: 0.5178617	total: 1.99s	remaining: 26.4s
# 70:	learn: 0.5176012	total: 2.01s	remaining: 26.3s
# 71:	learn: 0.5174282	total: 2.03s	remaining: 26.2s
# 72:	learn: 0.5172505	total: 2.05s	remaining: 26s
# 73:	learn: 0.5169804	total: 2.07s	remaining: 26s
# 74:	learn: 0.5167507	total: 2.1s	remaining: 25.9s
# 75:	learn: 0.5165897	total: 2.12s	remaining: 25.8s
# 76:	learn: 0.5163606	total: 2.14s	remaining: 25.7s
# 77:	learn: 0.5161940	total: 2.16s	remaining: 25.5s
# 78:	learn: 0.5160409	total: 2.18s	remaining: 25.5s
# 79:	learn: 0.5159078	total: 2.21s	remaining: 25.4s
# 80:	learn: 0.5157745	total: 2.23s	remaining: 25.3s
# 81:	learn: 0.5156148	total: 2.25s	remaining: 25.2s
# 82:	learn: 0.5154810	total: 2.27s	remaining: 25.1s
# 83:	learn: 0.5153563	total: 2.3s	remaining: 25s
# 84:	learn: 0.5152490	total: 2.32s	remaining: 25s
# 85:	learn: 0.5150695	total: 2.35s	remaining: 25s
# 86:	learn: 0.5149169	total: 2.38s	remaining: 25s
# 87:	learn: 0.5147254	total: 2.4s	remaining: 24.9s
# 88:	learn: 0.5145849	total: 2.43s	remaining: 24.9s
# 89:	learn: 0.5144222	total: 2.46s	remaining: 24.9s
# 90:	learn: 0.5143194	total: 2.49s	remaining: 24.9s
# 91:	learn: 0.5142272	total: 2.51s	remaining: 24.8s
# 92:	learn: 0.5140981	total: 2.54s	remaining: 24.8s
# 93:	learn: 0.5140041	total: 2.57s	remaining: 24.8s
# 94:	learn: 0.5139241	total: 2.59s	remaining: 24.7s
# 95:	learn: 0.5138433	total: 2.62s	remaining: 24.7s
# 96:	learn: 0.5137487	total: 2.65s	remaining: 24.7s
# 97:	learn: 0.5136604	total: 2.68s	remaining: 24.7s
# 98:	learn: 0.5135253	total: 2.7s	remaining: 24.6s
# 99:	learn: 0.5134303	total: 2.72s	remaining: 24.5s
# 100:	learn: 0.5133527	total: 2.75s	remaining: 24.5s
# 101:	learn: 0.5132736	total: 2.77s	remaining: 24.4s
# 102:	learn: 0.5131778	total: 2.79s	remaining: 24.3s
# 103:	learn: 0.5130633	total: 2.81s	remaining: 24.2s
# 104:	learn: 0.5129878	total: 2.83s	remaining: 24.1s
# 105:	learn: 0.5129151	total: 2.85s	remaining: 24s
# 106:	learn: 0.5128389	total: 2.87s	remaining: 23.9s
# 107:	learn: 0.5127428	total: 2.9s	remaining: 24s
# 108:	learn: 0.5126743	total: 2.94s	remaining: 24s
# 109:	learn: 0.5125940	total: 2.96s	remaining: 23.9s
# 110:	learn: 0.5125206	total: 2.98s	remaining: 23.9s
# 111:	learn: 0.5124483	total: 3.02s	remaining: 23.9s
# 112:	learn: 0.5123890	total: 3.04s	remaining: 23.9s
# 113:	learn: 0.5123147	total: 3.07s	remaining: 23.8s
# 114:	learn: 0.5122428	total: 3.1s	remaining: 23.8s
# 115:	learn: 0.5121717	total: 3.13s	remaining: 23.9s
# 116:	learn: 0.5120799	total: 3.15s	remaining: 23.8s
# 117:	learn: 0.5120322	total: 3.18s	remaining: 23.8s
# 118:	learn: 0.5119767	total: 3.21s	remaining: 23.8s
# 119:	learn: 0.5118849	total: 3.24s	remaining: 23.8s
# 120:	learn: 0.5118312	total: 3.26s	remaining: 23.7s
# 121:	learn: 0.5117709	total: 3.3s	remaining: 23.7s
# 122:	learn: 0.5117019	total: 3.33s	remaining: 23.7s
# 123:	learn: 0.5116329	total: 3.35s	remaining: 23.7s
# 124:	learn: 0.5115811	total: 3.38s	remaining: 23.7s
# 125:	learn: 0.5115222	total: 3.41s	remaining: 23.6s
# 126:	learn: 0.5114698	total: 3.44s	remaining: 23.6s
# 127:	learn: 0.5113876	total: 3.46s	remaining: 23.6s
# 128:	learn: 0.5113355	total: 3.49s	remaining: 23.6s
# 129:	learn: 0.5112759	total: 3.52s	remaining: 23.6s
# 130:	learn: 0.5112154	total: 3.55s	remaining: 23.5s
# 131:	learn: 0.5111632	total: 3.57s	remaining: 23.5s
# 132:	learn: 0.5110967	total: 3.6s	remaining: 23.5s
# 133:	learn: 0.5110297	total: 3.63s	remaining: 23.5s
# 134:	learn: 0.5109925	total: 3.65s	remaining: 23.4s
# 135:	learn: 0.5109272	total: 3.69s	remaining: 23.4s
# 136:	learn: 0.5108973	total: 3.72s	remaining: 23.4s
# 137:	learn: 0.5108329	total: 3.74s	remaining: 23.4s
# 138:	learn: 0.5107910	total: 3.76s	remaining: 23.3s
# 139:	learn: 0.5107426	total: 3.79s	remaining: 23.3s
# 140:	learn: 0.5107041	total: 3.83s	remaining: 23.3s
# 141:	learn: 0.5106621	total: 3.85s	remaining: 23.3s
# 142:	learn: 0.5106130	total: 3.88s	remaining: 23.3s
# 143:	learn: 0.5105679	total: 3.91s	remaining: 23.3s
# 144:	learn: 0.5105262	total: 3.94s	remaining: 23.2s
# 145:	learn: 0.5105004	total: 3.97s	remaining: 23.2s
# 146:	learn: 0.5104598	total: 4s	remaining: 23.2s
# 147:	learn: 0.5104061	total: 4.03s	remaining: 23.2s
# 148:	learn: 0.5103651	total: 4.05s	remaining: 23.1s
# 149:	learn: 0.5103113	total: 4.08s	remaining: 23.1s
# 150:	learn: 0.5102774	total: 4.12s	remaining: 23.1s
# 151:	learn: 0.5102527	total: 4.14s	remaining: 23.1s
# 152:	learn: 0.5102325	total: 4.17s	remaining: 23.1s
# 153:	learn: 0.5101794	total: 4.2s	remaining: 23.1s
# 154:	learn: 0.5101543	total: 4.23s	remaining: 23.1s
# 155:	learn: 0.5101151	total: 4.25s	remaining: 23s
# 156:	learn: 0.5100796	total: 4.28s	remaining: 23s
# 157:	learn: 0.5100416	total: 4.31s	remaining: 23s
# 158:	learn: 0.5100045	total: 4.34s	remaining: 22.9s
# 159:	learn: 0.5099671	total: 4.36s	remaining: 22.9s
# 160:	learn: 0.5099461	total: 4.38s	remaining: 22.8s
# 161:	learn: 0.5099061	total: 4.4s	remaining: 22.8s
# 162:	learn: 0.5098702	total: 4.43s	remaining: 22.7s
# 163:	learn: 0.5098401	total: 4.45s	remaining: 22.7s
# 164:	learn: 0.5097728	total: 4.48s	remaining: 22.7s
# 165:	learn: 0.5097088	total: 4.52s	remaining: 22.7s
# 166:	learn: 0.5096739	total: 4.54s	remaining: 22.7s
# 167:	learn: 0.5096506	total: 4.57s	remaining: 22.6s
# 168:	learn: 0.5096209	total: 4.6s	remaining: 22.6s
# 169:	learn: 0.5095902	total: 4.62s	remaining: 22.5s
# 170:	learn: 0.5095702	total: 4.65s	remaining: 22.5s
# 171:	learn: 0.5095409	total: 4.68s	remaining: 22.5s
# 172:	learn: 0.5095068	total: 4.7s	remaining: 22.5s
# 173:	learn: 0.5094832	total: 4.73s	remaining: 22.4s
# 174:	learn: 0.5094227	total: 4.75s	remaining: 22.4s
# 175:	learn: 0.5093857	total: 4.78s	remaining: 22.4s
# 176:	learn: 0.5093590	total: 4.8s	remaining: 22.3s
# 177:	learn: 0.5093237	total: 4.83s	remaining: 22.3s
# 178:	learn: 0.5092983	total: 4.86s	remaining: 22.3s
# 179:	learn: 0.5092605	total: 4.89s	remaining: 22.3s
# 180:	learn: 0.5092189	total: 4.91s	remaining: 22.2s
# 181:	learn: 0.5091989	total: 4.94s	remaining: 22.2s
# 182:	learn: 0.5091788	total: 4.98s	remaining: 22.2s
# 183:	learn: 0.5091509	total: 5s	remaining: 22.2s
# 184:	learn: 0.5091218	total: 5.03s	remaining: 22.2s
# 185:	learn: 0.5090968	total: 5.06s	remaining: 22.2s
# 186:	learn: 0.5090706	total: 5.09s	remaining: 22.1s
# 187:	learn: 0.5090544	total: 5.11s	remaining: 22.1s
# 188:	learn: 0.5090414	total: 5.14s	remaining: 22.1s
# 189:	learn: 0.5090126	total: 5.17s	remaining: 22.1s
# 190:	learn: 0.5089877	total: 5.2s	remaining: 22s
# 191:	learn: 0.5089259	total: 5.22s	remaining: 22s
# 192:	learn: 0.5088895	total: 5.26s	remaining: 22s
# 193:	learn: 0.5088651	total: 5.29s	remaining: 22s
# 194:	learn: 0.5088355	total: 5.31s	remaining: 21.9s
# 195:	learn: 0.5087946	total: 5.33s	remaining: 21.9s
# 196:	learn: 0.5087623	total: 5.36s	remaining: 21.8s
# 197:	learn: 0.5087379	total: 5.38s	remaining: 21.8s
# 198:	learn: 0.5087229	total: 5.41s	remaining: 21.8s
# 199:	learn: 0.5087087	total: 5.44s	remaining: 21.8s
# 200:	learn: 0.5086666	total: 5.47s	remaining: 21.7s
# 201:	learn: 0.5086449	total: 5.49s	remaining: 21.7s
# 202:	learn: 0.5086290	total: 5.52s	remaining: 21.7s
# 203:	learn: 0.5086068	total: 5.56s	remaining: 21.7s
# 204:	learn: 0.5085699	total: 5.58s	remaining: 21.6s
# 205:	learn: 0.5085375	total: 5.61s	remaining: 21.6s
# 206:	learn: 0.5085108	total: 5.63s	remaining: 21.6s
# 207:	learn: 0.5084941	total: 5.66s	remaining: 21.6s
# 208:	learn: 0.5084750	total: 5.68s	remaining: 21.5s
# 209:	learn: 0.5084559	total: 5.71s	remaining: 21.5s
# 210:	learn: 0.5084458	total: 5.73s	remaining: 21.4s
# 211:	learn: 0.5084218	total: 5.76s	remaining: 21.4s
# 212:	learn: 0.5084094	total: 5.78s	remaining: 21.4s
# 213:	learn: 0.5083775	total: 5.81s	remaining: 21.3s
# 214:	learn: 0.5083454	total: 5.84s	remaining: 21.3s
# 215:	learn: 0.5083237	total: 5.87s	remaining: 21.3s
# 216:	learn: 0.5083065	total: 5.89s	remaining: 21.2s
# 217:	learn: 0.5082938	total: 5.92s	remaining: 21.2s
# 218:	learn: 0.5082752	total: 5.95s	remaining: 21.2s
# 219:	learn: 0.5082597	total: 5.97s	remaining: 21.2s
# 220:	learn: 0.5082429	total: 6s	remaining: 21.1s
# 221:	learn: 0.5082189	total: 6.03s	remaining: 21.1s
# 222:	learn: 0.5082043	total: 6.06s	remaining: 21.1s
# 223:	learn: 0.5081763	total: 6.07s	remaining: 21s
# 224:	learn: 0.5081574	total: 6.11s	remaining: 21s
# 225:	learn: 0.5081452	total: 6.13s	remaining: 21s
# 226:	learn: 0.5081271	total: 6.16s	remaining: 21s
# 227:	learn: 0.5081085	total: 6.2s	remaining: 21s
# 228:	learn: 0.5080904	total: 6.23s	remaining: 21s
# 229:	learn: 0.5080743	total: 6.26s	remaining: 21s
# 230:	learn: 0.5080558	total: 6.29s	remaining: 20.9s
# 231:	learn: 0.5080270	total: 6.32s	remaining: 20.9s
# 232:	learn: 0.5080121	total: 6.34s	remaining: 20.9s
# 233:	learn: 0.5079810	total: 6.36s	remaining: 20.8s
# 234:	learn: 0.5079700	total: 6.39s	remaining: 20.8s
# 235:	learn: 0.5079481	total: 6.43s	remaining: 20.8s
# 236:	learn: 0.5079355	total: 6.45s	remaining: 20.8s
# 237:	learn: 0.5079108	total: 6.48s	remaining: 20.7s
# 238:	learn: 0.5078913	total: 6.51s	remaining: 20.7s
# 239:	learn: 0.5078734	total: 6.54s	remaining: 20.7s
# 240:	learn: 0.5078570	total: 6.56s	remaining: 20.6s
# 241:	learn: 0.5078400	total: 6.59s	remaining: 20.6s
# 242:	learn: 0.5078239	total: 6.62s	remaining: 20.6s
# 243:	learn: 0.5078089	total: 6.64s	remaining: 20.6s
# 244:	learn: 0.5077917	total: 6.67s	remaining: 20.5s
# 245:	learn: 0.5077781	total: 6.69s	remaining: 20.5s
# 246:	learn: 0.5077637	total: 6.71s	remaining: 20.5s
# 247:	learn: 0.5077525	total: 6.73s	remaining: 20.4s
# 248:	learn: 0.5077312	total: 6.76s	remaining: 20.4s
# 249:	learn: 0.5077197	total: 6.79s	remaining: 20.4s
# 250:	learn: 0.5077020	total: 6.82s	remaining: 20.3s
# 251:	learn: 0.5076769	total: 6.84s	remaining: 20.3s
# 252:	learn: 0.5076569	total: 6.87s	remaining: 20.3s
# 253:	learn: 0.5076447	total: 6.9s	remaining: 20.3s
# 254:	learn: 0.5076292	total: 6.93s	remaining: 20.2s
# 255:	learn: 0.5076178	total: 6.94s	remaining: 20.2s
# 256:	learn: 0.5076039	total: 6.98s	remaining: 20.2s
# 257:	learn: 0.5075850	total: 7.02s	remaining: 20.2s
# 258:	learn: 0.5075634	total: 7.04s	remaining: 20.1s
# 259:	learn: 0.5075415	total: 7.07s	remaining: 20.1s
# 260:	learn: 0.5075333	total: 7.11s	remaining: 20.1s
# 261:	learn: 0.5075128	total: 7.13s	remaining: 20.1s
# 262:	learn: 0.5075014	total: 7.15s	remaining: 20.1s
# 263:	learn: 0.5074871	total: 7.18s	remaining: 20s
# 264:	learn: 0.5074755	total: 7.2s	remaining: 20s
# 265:	learn: 0.5074489	total: 7.22s	remaining: 19.9s
# 266:	learn: 0.5074345	total: 7.25s	remaining: 19.9s
# 267:	learn: 0.5074177	total: 7.28s	remaining: 19.9s
# 268:	learn: 0.5074057	total: 7.31s	remaining: 19.9s
# 269:	learn: 0.5073965	total: 7.34s	remaining: 19.8s
# 270:	learn: 0.5073718	total: 7.4s	remaining: 19.9s
# 271:	learn: 0.5073488	total: 7.43s	remaining: 19.9s
# 272:	learn: 0.5073336	total: 7.45s	remaining: 19.8s
# 273:	learn: 0.5073203	total: 7.48s	remaining: 19.8s
# 274:	learn: 0.5073101	total: 7.51s	remaining: 19.8s
# 275:	learn: 0.5072940	total: 7.53s	remaining: 19.8s
# 276:	learn: 0.5072777	total: 7.56s	remaining: 19.7s
# 277:	learn: 0.5072651	total: 7.59s	remaining: 19.7s
# 278:	learn: 0.5072510	total: 7.62s	remaining: 19.7s
# 279:	learn: 0.5072381	total: 7.64s	remaining: 19.7s
# 280:	learn: 0.5072259	total: 7.67s	remaining: 19.6s
# 281:	learn: 0.5072083	total: 7.71s	remaining: 19.6s
# 282:	learn: 0.5071741	total: 7.73s	remaining: 19.6s
# 283:	learn: 0.5071489	total: 7.76s	remaining: 19.6s
# 284:	learn: 0.5071343	total: 7.79s	remaining: 19.6s
# 285:	learn: 0.5071267	total: 7.82s	remaining: 19.5s
# 286:	learn: 0.5071145	total: 7.84s	remaining: 19.5s
# 287:	learn: 0.5071058	total: 7.86s	remaining: 19.4s
# 288:	learn: 0.5070877	total: 7.88s	remaining: 19.4s
# 289:	learn: 0.5070823	total: 7.91s	remaining: 19.4s
# 290:	learn: 0.5070703	total: 7.92s	remaining: 19.3s
# 291:	learn: 0.5070464	total: 7.95s	remaining: 19.3s
# 292:	learn: 0.5070312	total: 7.97s	remaining: 19.2s
# 293:	learn: 0.5070116	total: 8s	remaining: 19.2s
# 294:	learn: 0.5069982	total: 8.01s	remaining: 19.1s
# 295:	learn: 0.5069821	total: 8.04s	remaining: 19.1s
# 296:	learn: 0.5069608	total: 8.07s	remaining: 19.1s
# 297:	learn: 0.5069493	total: 8.1s	remaining: 19.1s
# 298:	learn: 0.5069345	total: 8.11s	remaining: 19s
# 299:	learn: 0.5069005	total: 8.14s	remaining: 19s
# 300:	learn: 0.5068879	total: 8.17s	remaining: 19s
# 301:	learn: 0.5068797	total: 8.2s	remaining: 18.9s
# 302:	learn: 0.5068581	total: 8.22s	remaining: 18.9s
# 303:	learn: 0.5068484	total: 8.25s	remaining: 18.9s
# 304:	learn: 0.5068384	total: 8.28s	remaining: 18.9s
# 305:	learn: 0.5068152	total: 8.3s	remaining: 18.8s
# 306:	learn: 0.5068037	total: 8.32s	remaining: 18.8s
# 307:	learn: 0.5068009	total: 8.34s	remaining: 18.7s
# 308:	learn: 0.5067799	total: 8.38s	remaining: 18.7s
# 309:	learn: 0.5067649	total: 8.4s	remaining: 18.7s
# 310:	learn: 0.5067551	total: 8.42s	remaining: 18.7s
# 311:	learn: 0.5067432	total: 8.44s	remaining: 18.6s
# 312:	learn: 0.5067204	total: 8.47s	remaining: 18.6s
# 313:	learn: 0.5067154	total: 8.49s	remaining: 18.5s
# 314:	learn: 0.5066878	total: 8.51s	remaining: 18.5s
# 315:	learn: 0.5066746	total: 8.54s	remaining: 18.5s
# 316:	learn: 0.5066580	total: 8.57s	remaining: 18.5s
# 317:	learn: 0.5066464	total: 8.59s	remaining: 18.4s
# 318:	learn: 0.5066425	total: 8.61s	remaining: 18.4s
# 319:	learn: 0.5066303	total: 8.64s	remaining: 18.4s
# 320:	learn: 0.5066174	total: 8.66s	remaining: 18.3s
# 321:	learn: 0.5066066	total: 8.69s	remaining: 18.3s
# 322:	learn: 0.5065946	total: 8.71s	remaining: 18.3s
# 323:	learn: 0.5065837	total: 8.74s	remaining: 18.2s
# 324:	learn: 0.5065721	total: 8.77s	remaining: 18.2s
# 325:	learn: 0.5065546	total: 8.79s	remaining: 18.2s
# 326:	learn: 0.5065421	total: 8.81s	remaining: 18.1s
# 327:	learn: 0.5065376	total: 8.84s	remaining: 18.1s
# 328:	learn: 0.5065275	total: 8.88s	remaining: 18.1s
# 329:	learn: 0.5065155	total: 8.89s	remaining: 18.1s
# 330:	learn: 0.5065057	total: 8.96s	remaining: 18.1s
# 331:	learn: 0.5064960	total: 8.99s	remaining: 18.1s
# 332:	learn: 0.5064849	total: 9.01s	remaining: 18.1s
# 333:	learn: 0.5064692	total: 9.04s	remaining: 18s
# 334:	learn: 0.5064562	total: 9.07s	remaining: 18s
# 335:	learn: 0.5064495	total: 9.1s	remaining: 18s
# 336:	learn: 0.5064320	total: 9.12s	remaining: 17.9s
# 337:	learn: 0.5064246	total: 9.15s	remaining: 17.9s
# 338:	learn: 0.5064135	total: 9.18s	remaining: 17.9s
# 339:	learn: 0.5064003	total: 9.2s	remaining: 17.9s
# 340:	learn: 0.5063890	total: 9.22s	remaining: 17.8s
# 341:	learn: 0.5063746	total: 9.25s	remaining: 17.8s
# 342:	learn: 0.5063621	total: 9.28s	remaining: 17.8s
# 343:	learn: 0.5063504	total: 9.3s	remaining: 17.7s
# 344:	learn: 0.5063346	total: 9.33s	remaining: 17.7s
# 345:	learn: 0.5063266	total: 9.35s	remaining: 17.7s
# 346:	learn: 0.5062994	total: 9.37s	remaining: 17.6s
# 347:	learn: 0.5062917	total: 9.39s	remaining: 17.6s
# 348:	learn: 0.5062689	total: 9.42s	remaining: 17.6s
# 349:	learn: 0.5062615	total: 9.45s	remaining: 17.6s
# 350:	learn: 0.5062526	total: 9.48s	remaining: 17.5s
# 351:	learn: 0.5062221	total: 9.5s	remaining: 17.5s
# 352:	learn: 0.5062065	total: 9.53s	remaining: 17.5s
# 353:	learn: 0.5061913	total: 9.56s	remaining: 17.4s
# 354:	learn: 0.5061827	total: 9.59s	remaining: 17.4s
# 355:	learn: 0.5061606	total: 9.6s	remaining: 17.4s
# 356:	learn: 0.5061527	total: 9.63s	remaining: 17.3s
# 357:	learn: 0.5061433	total: 9.66s	remaining: 17.3s
# 358:	learn: 0.5061346	total: 9.69s	remaining: 17.3s
# 359:	learn: 0.5061228	total: 9.7s	remaining: 17.3s
# 360:	learn: 0.5061136	total: 9.73s	remaining: 17.2s
# 361:	learn: 0.5061057	total: 9.77s	remaining: 17.2s
# 362:	learn: 0.5060910	total: 9.79s	remaining: 17.2s
# 363:	learn: 0.5060759	total: 9.81s	remaining: 17.1s
# 364:	learn: 0.5060615	total: 9.83s	remaining: 17.1s
# 365:	learn: 0.5060452	total: 9.85s	remaining: 17.1s
# 366:	learn: 0.5060450	total: 9.86s	remaining: 17s
# 367:	learn: 0.5060279	total: 9.87s	remaining: 17s
# 368:	learn: 0.5060145	total: 9.89s	remaining: 16.9s
# 369:	learn: 0.5060025	total: 9.91s	remaining: 16.9s
# 370:	learn: 0.5059900	total: 9.93s	remaining: 16.8s
# 371:	learn: 0.5059805	total: 9.95s	remaining: 16.8s
# 372:	learn: 0.5059666	total: 9.98s	remaining: 16.8s
# 373:	learn: 0.5059507	total: 10s	remaining: 16.8s
# 374:	learn: 0.5059380	total: 10s	remaining: 16.7s
# 375:	learn: 0.5059269	total: 10.1s	remaining: 16.7s
# 376:	learn: 0.5059168	total: 10.1s	remaining: 16.7s
# 377:	learn: 0.5059018	total: 10.1s	remaining: 16.6s
# 378:	learn: 0.5058908	total: 10.1s	remaining: 16.6s
# 379:	learn: 0.5058802	total: 10.2s	remaining: 16.6s
# 380:	learn: 0.5058655	total: 10.2s	remaining: 16.6s
# 381:	learn: 0.5058391	total: 10.2s	remaining: 16.5s
# 382:	learn: 0.5058157	total: 10.2s	remaining: 16.5s
# 383:	learn: 0.5058031	total: 10.3s	remaining: 16.5s
# 384:	learn: 0.5057932	total: 10.3s	remaining: 16.4s
# 385:	learn: 0.5057835	total: 10.3s	remaining: 16.4s
# 386:	learn: 0.5057773	total: 10.3s	remaining: 16.4s
# 387:	learn: 0.5057587	total: 10.3s	remaining: 16.3s
# 388:	learn: 0.5057507	total: 10.4s	remaining: 16.3s
# 389:	learn: 0.5057409	total: 10.4s	remaining: 16.3s
# 390:	learn: 0.5057328	total: 10.4s	remaining: 16.3s
# 391:	learn: 0.5057247	total: 10.5s	remaining: 16.2s
# 392:	learn: 0.5057065	total: 10.5s	remaining: 16.2s
# 393:	learn: 0.5056936	total: 10.5s	remaining: 16.2s
# 394:	learn: 0.5056806	total: 10.5s	remaining: 16.1s
# 395:	learn: 0.5056705	total: 10.6s	remaining: 16.1s
# 396:	learn: 0.5056568	total: 10.6s	remaining: 16.1s
# 397:	learn: 0.5056508	total: 10.6s	remaining: 16s
# 398:	learn: 0.5056372	total: 10.6s	remaining: 16s
# 399:	learn: 0.5056254	total: 10.7s	remaining: 16s
# 400:	learn: 0.5056076	total: 10.7s	remaining: 16s
# 401:	learn: 0.5055915	total: 10.7s	remaining: 15.9s
# 402:	learn: 0.5055768	total: 10.7s	remaining: 15.9s
# 403:	learn: 0.5055627	total: 10.8s	remaining: 15.9s
# 404:	learn: 0.5055518	total: 10.8s	remaining: 15.8s
# 405:	learn: 0.5055413	total: 10.8s	remaining: 15.8s
# 406:	learn: 0.5055260	total: 10.8s	remaining: 15.8s
# 407:	learn: 0.5055173	total: 10.9s	remaining: 15.8s
# 408:	learn: 0.5055074	total: 10.9s	remaining: 15.7s
# 409:	learn: 0.5054886	total: 10.9s	remaining: 15.7s
# 410:	learn: 0.5054812	total: 10.9s	remaining: 15.7s
# 411:	learn: 0.5054715	total: 11s	remaining: 15.6s
# 412:	learn: 0.5054620	total: 11s	remaining: 15.6s
# 413:	learn: 0.5054493	total: 11s	remaining: 15.6s
# 414:	learn: 0.5054410	total: 11s	remaining: 15.5s
# 415:	learn: 0.5054260	total: 11s	remaining: 15.5s
# 416:	learn: 0.5054198	total: 11s	remaining: 15.4s
# 417:	learn: 0.5054119	total: 11.1s	remaining: 15.4s
# 418:	learn: 0.5053966	total: 11.1s	remaining: 15.4s
# 419:	learn: 0.5053823	total: 11.1s	remaining: 15.3s
# 420:	learn: 0.5053576	total: 11.1s	remaining: 15.3s
# 421:	learn: 0.5053469	total: 11.2s	remaining: 15.3s
# 422:	learn: 0.5053328	total: 11.2s	remaining: 15.3s
# 423:	learn: 0.5053237	total: 11.2s	remaining: 15.2s
# 424:	learn: 0.5053124	total: 11.2s	remaining: 15.2s
# 425:	learn: 0.5052887	total: 11.3s	remaining: 15.2s
# 426:	learn: 0.5052768	total: 11.3s	remaining: 15.1s
# 427:	learn: 0.5052659	total: 11.3s	remaining: 15.1s
# 428:	learn: 0.5052541	total: 11.3s	remaining: 15.1s
# 429:	learn: 0.5052476	total: 11.4s	remaining: 15.1s
# 430:	learn: 0.5052409	total: 11.4s	remaining: 15s
# 431:	learn: 0.5052286	total: 11.4s	remaining: 15s
# 432:	learn: 0.5052144	total: 11.4s	remaining: 15s
# 433:	learn: 0.5051997	total: 11.5s	remaining: 14.9s
# 434:	learn: 0.5051908	total: 11.5s	remaining: 14.9s
# 435:	learn: 0.5051718	total: 11.5s	remaining: 14.9s
# 436:	learn: 0.5051524	total: 11.5s	remaining: 14.9s
# 437:	learn: 0.5051417	total: 11.6s	remaining: 14.8s
# 438:	learn: 0.5051279	total: 11.6s	remaining: 14.8s
# 439:	learn: 0.5051149	total: 11.6s	remaining: 14.8s
# 440:	learn: 0.5051033	total: 11.6s	remaining: 14.7s
# 441:	learn: 0.5050943	total: 11.7s	remaining: 14.7s
# 442:	learn: 0.5050836	total: 11.7s	remaining: 14.7s
# 443:	learn: 0.5050724	total: 11.7s	remaining: 14.7s
# 444:	learn: 0.5050648	total: 11.7s	remaining: 14.6s
# 445:	learn: 0.5050532	total: 11.7s	remaining: 14.6s
# 446:	learn: 0.5050447	total: 11.8s	remaining: 14.6s
# 447:	learn: 0.5050326	total: 11.8s	remaining: 14.5s
# 448:	learn: 0.5050163	total: 11.8s	remaining: 14.5s
# 449:	learn: 0.5050085	total: 11.8s	remaining: 14.5s
# 450:	learn: 0.5049913	total: 11.9s	remaining: 14.5s
# 451:	learn: 0.5049725	total: 11.9s	remaining: 14.4s
# 452:	learn: 0.5049604	total: 11.9s	remaining: 14.4s
# 453:	learn: 0.5049527	total: 11.9s	remaining: 14.4s
# 454:	learn: 0.5049412	total: 12s	remaining: 14.3s
# 455:	learn: 0.5049303	total: 12s	remaining: 14.3s
# 456:	learn: 0.5049187	total: 12s	remaining: 14.3s
# 457:	learn: 0.5049113	total: 12.1s	remaining: 14.3s
# 458:	learn: 0.5049002	total: 12.1s	remaining: 14.2s
# 459:	learn: 0.5048824	total: 12.1s	remaining: 14.2s
# 460:	learn: 0.5048743	total: 12.1s	remaining: 14.2s
# 461:	learn: 0.5048655	total: 12.2s	remaining: 14.2s
# 462:	learn: 0.5048535	total: 12.2s	remaining: 14.1s
# 463:	learn: 0.5048409	total: 12.2s	remaining: 14.1s
# 464:	learn: 0.5048282	total: 12.2s	remaining: 14.1s
# 465:	learn: 0.5048160	total: 12.3s	remaining: 14.1s
# 466:	learn: 0.5048042	total: 12.3s	remaining: 14s
# 467:	learn: 0.5047894	total: 12.3s	remaining: 14s
# 468:	learn: 0.5047751	total: 12.4s	remaining: 14s
# 469:	learn: 0.5047637	total: 12.4s	remaining: 14s
# 470:	learn: 0.5047506	total: 12.4s	remaining: 13.9s
# 471:	learn: 0.5047388	total: 12.4s	remaining: 13.9s
# 472:	learn: 0.5047251	total: 12.5s	remaining: 13.9s
# 473:	learn: 0.5047162	total: 12.5s	remaining: 13.9s
# 474:	learn: 0.5047038	total: 12.5s	remaining: 13.8s
# 475:	learn: 0.5046955	total: 12.5s	remaining: 13.8s
# 476:	learn: 0.5046837	total: 12.6s	remaining: 13.8s
# 477:	learn: 0.5046769	total: 12.6s	remaining: 13.7s
# 478:	learn: 0.5046655	total: 12.6s	remaining: 13.7s
# 479:	learn: 0.5046423	total: 12.6s	remaining: 13.7s
# 480:	learn: 0.5046342	total: 12.7s	remaining: 13.7s
# 481:	learn: 0.5046271	total: 12.7s	remaining: 13.6s
# 482:	learn: 0.5046158	total: 12.7s	remaining: 13.6s
# 483:	learn: 0.5046057	total: 12.7s	remaining: 13.6s
# 484:	learn: 0.5045856	total: 12.7s	remaining: 13.5s
# 485:	learn: 0.5045697	total: 12.8s	remaining: 13.5s
# 486:	learn: 0.5045594	total: 12.8s	remaining: 13.5s
# 487:	learn: 0.5045477	total: 12.8s	remaining: 13.4s
# 488:	learn: 0.5045380	total: 12.8s	remaining: 13.4s
# 489:	learn: 0.5045313	total: 12.9s	remaining: 13.4s
# 490:	learn: 0.5045172	total: 12.9s	remaining: 13.3s
# 491:	learn: 0.5045066	total: 12.9s	remaining: 13.3s
# 492:	learn: 0.5044888	total: 12.9s	remaining: 13.3s
# 493:	learn: 0.5044773	total: 12.9s	remaining: 13.3s
# 494:	learn: 0.5044564	total: 13s	remaining: 13.2s
# 495:	learn: 0.5044428	total: 13s	remaining: 13.2s
# 496:	learn: 0.5044274	total: 13s	remaining: 13.2s
# 497:	learn: 0.5044187	total: 13s	remaining: 13.1s
# 498:	learn: 0.5044083	total: 13.1s	remaining: 13.1s
# 499:	learn: 0.5044016	total: 13.1s	remaining: 13.1s
# 500:	learn: 0.5043850	total: 13.1s	remaining: 13.1s
# 501:	learn: 0.5043747	total: 13.1s	remaining: 13s
# 502:	learn: 0.5043647	total: 13.2s	remaining: 13s
# 503:	learn: 0.5043569	total: 13.2s	remaining: 13s
# 504:	learn: 0.5043420	total: 13.2s	remaining: 12.9s
# 505:	learn: 0.5043322	total: 13.2s	remaining: 12.9s
# 506:	learn: 0.5043242	total: 13.3s	remaining: 12.9s
# 507:	learn: 0.5043092	total: 13.3s	remaining: 12.9s
# 508:	learn: 0.5042973	total: 13.3s	remaining: 12.8s
# 509:	learn: 0.5042860	total: 13.3s	remaining: 12.8s
# 510:	learn: 0.5042689	total: 13.4s	remaining: 12.8s
# 511:	learn: 0.5042573	total: 13.4s	remaining: 12.8s
# 512:	learn: 0.5042444	total: 13.4s	remaining: 12.7s
# 513:	learn: 0.5042306	total: 13.4s	remaining: 12.7s
# 514:	learn: 0.5042195	total: 13.4s	remaining: 12.7s
# 515:	learn: 0.5042065	total: 13.5s	remaining: 12.6s
# 516:	learn: 0.5041869	total: 13.5s	remaining: 12.6s
# 517:	learn: 0.5041752	total: 13.5s	remaining: 12.6s
# 518:	learn: 0.5041671	total: 13.5s	remaining: 12.5s
# 519:	learn: 0.5041613	total: 13.6s	remaining: 12.5s
# 520:	learn: 0.5041488	total: 13.6s	remaining: 12.5s
# 521:	learn: 0.5041342	total: 13.6s	remaining: 12.4s
# 522:	learn: 0.5041234	total: 13.6s	remaining: 12.4s
# 523:	learn: 0.5041145	total: 13.6s	remaining: 12.4s
# 524:	learn: 0.5041036	total: 13.7s	remaining: 12.4s
# 525:	learn: 0.5040909	total: 13.7s	remaining: 12.3s
# 526:	learn: 0.5040780	total: 13.7s	remaining: 12.3s
# 527:	learn: 0.5040704	total: 13.7s	remaining: 12.3s
# 528:	learn: 0.5040631	total: 13.8s	remaining: 12.3s
# 529:	learn: 0.5040557	total: 13.8s	remaining: 12.2s
# 530:	learn: 0.5040441	total: 13.8s	remaining: 12.2s
# 531:	learn: 0.5040297	total: 13.8s	remaining: 12.2s
# 532:	learn: 0.5040204	total: 13.9s	remaining: 12.1s
# 533:	learn: 0.5040072	total: 13.9s	remaining: 12.1s
# 534:	learn: 0.5040006	total: 13.9s	remaining: 12.1s
# 535:	learn: 0.5039902	total: 13.9s	remaining: 12.1s
# 536:	learn: 0.5039802	total: 13.9s	remaining: 12s
# 537:	learn: 0.5039654	total: 14s	remaining: 12s
# 538:	learn: 0.5039564	total: 14s	remaining: 12s
# 539:	learn: 0.5039407	total: 14s	remaining: 11.9s
# 540:	learn: 0.5039281	total: 14s	remaining: 11.9s
# 541:	learn: 0.5039165	total: 14.1s	remaining: 11.9s
# 542:	learn: 0.5039084	total: 14.1s	remaining: 11.9s
# 543:	learn: 0.5038965	total: 14.1s	remaining: 11.8s
# 544:	learn: 0.5038871	total: 14.2s	remaining: 11.8s
# 545:	learn: 0.5038730	total: 14.2s	remaining: 11.8s
# 546:	learn: 0.5038592	total: 14.2s	remaining: 11.8s
# 547:	learn: 0.5038476	total: 14.2s	remaining: 11.7s
# 548:	learn: 0.5038404	total: 14.2s	remaining: 11.7s
# 549:	learn: 0.5038294	total: 14.3s	remaining: 11.7s
# 550:	learn: 0.5038226	total: 14.3s	remaining: 11.6s
# 551:	learn: 0.5038053	total: 14.3s	remaining: 11.6s
# 552:	learn: 0.5037908	total: 14.3s	remaining: 11.6s
# 553:	learn: 0.5037826	total: 14.4s	remaining: 11.6s
# 554:	learn: 0.5037727	total: 14.4s	remaining: 11.6s
# 555:	learn: 0.5037655	total: 14.4s	remaining: 11.5s
# 556:	learn: 0.5037518	total: 14.5s	remaining: 11.5s
# 557:	learn: 0.5037474	total: 14.5s	remaining: 11.5s
# 558:	learn: 0.5037350	total: 14.5s	remaining: 11.4s
# 559:	learn: 0.5037266	total: 14.5s	remaining: 11.4s
# 560:	learn: 0.5037161	total: 14.5s	remaining: 11.4s
# 561:	learn: 0.5037073	total: 14.6s	remaining: 11.4s
# 562:	learn: 0.5036925	total: 14.6s	remaining: 11.3s
# 563:	learn: 0.5036792	total: 14.6s	remaining: 11.3s
# 564:	learn: 0.5036709	total: 14.6s	remaining: 11.3s
# 565:	learn: 0.5036610	total: 14.7s	remaining: 11.2s
# 566:	learn: 0.5036506	total: 14.7s	remaining: 11.2s
# 567:	learn: 0.5036455	total: 14.7s	remaining: 11.2s
# 568:	learn: 0.5036339	total: 14.7s	remaining: 11.1s
# 569:	learn: 0.5036226	total: 14.7s	remaining: 11.1s
# 570:	learn: 0.5036143	total: 14.8s	remaining: 11.1s
# 571:	learn: 0.5035973	total: 14.8s	remaining: 11.1s
# 572:	learn: 0.5035882	total: 14.8s	remaining: 11s
# 573:	learn: 0.5035780	total: 14.8s	remaining: 11s
# 574:	learn: 0.5035700	total: 14.9s	remaining: 11s
# 575:	learn: 0.5035586	total: 14.9s	remaining: 11s
# 576:	learn: 0.5035527	total: 14.9s	remaining: 10.9s
# 577:	learn: 0.5035397	total: 14.9s	remaining: 10.9s
# 578:	learn: 0.5035311	total: 15s	remaining: 10.9s
# 579:	learn: 0.5035223	total: 15s	remaining: 10.9s
# 580:	learn: 0.5035172	total: 15s	remaining: 10.8s
# 581:	learn: 0.5035043	total: 15.1s	remaining: 10.8s
# 582:	learn: 0.5034956	total: 15.1s	remaining: 10.8s
# 583:	learn: 0.5034836	total: 15.1s	remaining: 10.8s
# 584:	learn: 0.5034705	total: 15.1s	remaining: 10.7s
# 585:	learn: 0.5034643	total: 15.1s	remaining: 10.7s
# 586:	learn: 0.5034520	total: 15.2s	remaining: 10.7s
# 587:	learn: 0.5034463	total: 15.2s	remaining: 10.6s
# 588:	learn: 0.5034300	total: 15.2s	remaining: 10.6s
# 589:	learn: 0.5034245	total: 15.2s	remaining: 10.6s
# 590:	learn: 0.5034155	total: 15.3s	remaining: 10.6s
# 591:	learn: 0.5034062	total: 15.3s	remaining: 10.5s
# 592:	learn: 0.5033931	total: 15.3s	remaining: 10.5s
# 593:	learn: 0.5033822	total: 15.3s	remaining: 10.5s
# 594:	learn: 0.5033684	total: 15.4s	remaining: 10.5s
# 595:	learn: 0.5033593	total: 15.4s	remaining: 10.4s
# 596:	learn: 0.5033487	total: 15.4s	remaining: 10.4s
# 597:	learn: 0.5033382	total: 15.4s	remaining: 10.4s
# 598:	learn: 0.5033287	total: 15.5s	remaining: 10.4s
# 599:	learn: 0.5033172	total: 15.5s	remaining: 10.3s
# 600:	learn: 0.5033046	total: 15.5s	remaining: 10.3s
# 601:	learn: 0.5032946	total: 15.5s	remaining: 10.3s
# 602:	learn: 0.5032897	total: 15.6s	remaining: 10.2s
# 603:	learn: 0.5032807	total: 15.6s	remaining: 10.2s
# 604:	learn: 0.5032687	total: 15.6s	remaining: 10.2s
# 605:	learn: 0.5032591	total: 15.6s	remaining: 10.2s
# 606:	learn: 0.5032452	total: 15.6s	remaining: 10.1s
# 607:	learn: 0.5032380	total: 15.7s	remaining: 10.1s
# 608:	learn: 0.5032324	total: 15.7s	remaining: 10.1s
# 609:	learn: 0.5032219	total: 15.7s	remaining: 10.1s
# 610:	learn: 0.5032135	total: 15.7s	remaining: 10s
# 611:	learn: 0.5031987	total: 15.8s	remaining: 10s
# 612:	learn: 0.5031863	total: 15.8s	remaining: 9.97s
# 613:	learn: 0.5031788	total: 15.8s	remaining: 9.94s
# 614:	learn: 0.5031651	total: 15.8s	remaining: 9.91s
# 615:	learn: 0.5031556	total: 15.9s	remaining: 9.88s
# 616:	learn: 0.5031502	total: 15.9s	remaining: 9.86s
# 617:	learn: 0.5031410	total: 15.9s	remaining: 9.84s
# 618:	learn: 0.5031343	total: 15.9s	remaining: 9.81s
# 619:	learn: 0.5031237	total: 16s	remaining: 9.78s
# 620:	learn: 0.5031147	total: 16s	remaining: 9.76s
# 621:	learn: 0.5031012	total: 16s	remaining: 9.73s
# 622:	learn: 0.5030909	total: 16s	remaining: 9.7s
# 623:	learn: 0.5030797	total: 16.1s	remaining: 9.68s
# 624:	learn: 0.5030712	total: 16.1s	remaining: 9.65s
# 625:	learn: 0.5030634	total: 16.1s	remaining: 9.62s
# 626:	learn: 0.5030586	total: 16.1s	remaining: 9.59s
# 627:	learn: 0.5030498	total: 16.2s	remaining: 9.57s
# 628:	learn: 0.5030368	total: 16.2s	remaining: 9.55s
# 629:	learn: 0.5030258	total: 16.2s	remaining: 9.52s
# 630:	learn: 0.5030144	total: 16.2s	remaining: 9.49s
# 631:	learn: 0.5030066	total: 16.2s	remaining: 9.46s
# 632:	learn: 0.5030008	total: 16.3s	remaining: 9.43s
# 633:	learn: 0.5029930	total: 16.3s	remaining: 9.4s
# 634:	learn: 0.5029858	total: 16.3s	remaining: 9.38s
# 635:	learn: 0.5029770	total: 16.3s	remaining: 9.36s
# 636:	learn: 0.5029697	total: 16.4s	remaining: 9.33s
# 637:	learn: 0.5029607	total: 16.4s	remaining: 9.31s
# 638:	learn: 0.5029501	total: 16.4s	remaining: 9.28s
# 639:	learn: 0.5029414	total: 16.4s	remaining: 9.25s
# 640:	learn: 0.5029335	total: 16.5s	remaining: 9.22s
# 641:	learn: 0.5029254	total: 16.5s	remaining: 9.19s
# 642:	learn: 0.5029189	total: 16.5s	remaining: 9.16s
# 643:	learn: 0.5029124	total: 16.5s	remaining: 9.13s
# 644:	learn: 0.5029054	total: 16.6s	remaining: 9.11s
# 645:	learn: 0.5029018	total: 16.6s	remaining: 9.08s
# 646:	learn: 0.5028897	total: 16.6s	remaining: 9.05s
# 647:	learn: 0.5028782	total: 16.6s	remaining: 9.03s
# 648:	learn: 0.5028687	total: 16.6s	remaining: 9s
# 649:	learn: 0.5028598	total: 16.7s	remaining: 8.97s
# 650:	learn: 0.5028529	total: 16.7s	remaining: 8.94s
# 651:	learn: 0.5028409	total: 16.7s	remaining: 8.92s
# 652:	learn: 0.5028258	total: 16.7s	remaining: 8.9s
# 653:	learn: 0.5028168	total: 16.8s	remaining: 8.87s
# 654:	learn: 0.5028036	total: 16.8s	remaining: 8.84s
# 655:	learn: 0.5027946	total: 16.8s	remaining: 8.82s
# 656:	learn: 0.5027884	total: 16.8s	remaining: 8.79s
# 657:	learn: 0.5027797	total: 16.9s	remaining: 8.76s
# 658:	learn: 0.5027683	total: 16.9s	remaining: 8.74s
# 659:	learn: 0.5027587	total: 16.9s	remaining: 8.71s
# 660:	learn: 0.5027489	total: 16.9s	remaining: 8.69s
# 661:	learn: 0.5027392	total: 17s	remaining: 8.66s
# 662:	learn: 0.5027287	total: 17s	remaining: 8.64s
# 663:	learn: 0.5027185	total: 17s	remaining: 8.61s
# 664:	learn: 0.5027055	total: 17s	remaining: 8.58s
# 665:	learn: 0.5026951	total: 17.1s	remaining: 8.55s
# 666:	learn: 0.5026831	total: 17.1s	remaining: 8.53s
# 667:	learn: 0.5026718	total: 17.1s	remaining: 8.5s
# 668:	learn: 0.5026647	total: 17.1s	remaining: 8.48s
# 669:	learn: 0.5026549	total: 17.2s	remaining: 8.45s
# 670:	learn: 0.5026485	total: 17.2s	remaining: 8.42s
# 671:	learn: 0.5026370	total: 17.2s	remaining: 8.4s
# 672:	learn: 0.5026290	total: 17.2s	remaining: 8.37s
# 673:	learn: 0.5026179	total: 17.3s	remaining: 8.35s
# 674:	learn: 0.5026133	total: 17.3s	remaining: 8.32s
# 675:	learn: 0.5026013	total: 17.3s	remaining: 8.29s
# 676:	learn: 0.5025937	total: 17.3s	remaining: 8.27s
# 677:	learn: 0.5025859	total: 17.4s	remaining: 8.24s
# 678:	learn: 0.5025770	total: 17.4s	remaining: 8.22s
# 679:	learn: 0.5025694	total: 17.4s	remaining: 8.19s
# 680:	learn: 0.5025614	total: 17.4s	remaining: 8.16s
# 681:	learn: 0.5025552	total: 17.4s	remaining: 8.14s
# 682:	learn: 0.5025471	total: 17.5s	remaining: 8.11s
# 683:	learn: 0.5025357	total: 17.5s	remaining: 8.08s
# 684:	learn: 0.5025255	total: 17.5s	remaining: 8.05s
# 685:	learn: 0.5025156	total: 17.5s	remaining: 8.03s
# 686:	learn: 0.5025056	total: 17.6s	remaining: 8s
# 687:	learn: 0.5024946	total: 17.6s	remaining: 7.98s
# 688:	learn: 0.5024903	total: 17.6s	remaining: 7.95s
# 689:	learn: 0.5024797	total: 17.6s	remaining: 7.92s
# 690:	learn: 0.5024732	total: 17.7s	remaining: 7.9s
# 691:	learn: 0.5024645	total: 17.7s	remaining: 7.88s
# 692:	learn: 0.5024553	total: 17.7s	remaining: 7.85s
# 693:	learn: 0.5024475	total: 17.7s	remaining: 7.82s
# 694:	learn: 0.5024397	total: 17.8s	remaining: 7.79s
# 695:	learn: 0.5024323	total: 17.8s	remaining: 7.77s
# 696:	learn: 0.5024173	total: 17.8s	remaining: 7.74s
# 697:	learn: 0.5024100	total: 17.8s	remaining: 7.71s
# 698:	learn: 0.5024007	total: 17.9s	remaining: 7.69s
# 699:	learn: 0.5023908	total: 17.9s	remaining: 7.66s
# 700:	learn: 0.5023785	total: 17.9s	remaining: 7.63s
# 701:	learn: 0.5023688	total: 17.9s	remaining: 7.61s
# 702:	learn: 0.5023597	total: 17.9s	remaining: 7.58s
# 703:	learn: 0.5023515	total: 18s	remaining: 7.55s
# 704:	learn: 0.5023383	total: 18s	remaining: 7.53s
# 705:	learn: 0.5023270	total: 18s	remaining: 7.51s
# 706:	learn: 0.5023193	total: 18.1s	remaining: 7.48s
# 707:	learn: 0.5023094	total: 18.1s	remaining: 7.45s
# 708:	learn: 0.5022992	total: 18.1s	remaining: 7.43s
# 709:	learn: 0.5022877	total: 18.1s	remaining: 7.41s
# 710:	learn: 0.5022796	total: 18.2s	remaining: 7.38s
# 711:	learn: 0.5022690	total: 18.2s	remaining: 7.35s
# 712:	learn: 0.5022577	total: 18.2s	remaining: 7.33s
# 713:	learn: 0.5022496	total: 18.2s	remaining: 7.3s
# 714:	learn: 0.5022457	total: 18.2s	remaining: 7.27s
# 715:	learn: 0.5022361	total: 18.3s	remaining: 7.24s
# 716:	learn: 0.5022273	total: 18.3s	remaining: 7.21s
# 717:	learn: 0.5022222	total: 18.3s	remaining: 7.18s
# 718:	learn: 0.5022101	total: 18.3s	remaining: 7.16s
# 719:	learn: 0.5021978	total: 18.3s	remaining: 7.13s
# 720:	learn: 0.5021913	total: 18.4s	remaining: 7.11s
# 721:	learn: 0.5021804	total: 18.4s	remaining: 7.08s
# 722:	learn: 0.5021721	total: 18.4s	remaining: 7.05s
# 723:	learn: 0.5021674	total: 18.4s	remaining: 7.03s
# 724:	learn: 0.5021587	total: 18.5s	remaining: 7s
# 725:	learn: 0.5021516	total: 18.5s	remaining: 6.97s
# 726:	learn: 0.5021403	total: 18.5s	remaining: 6.95s
# 727:	learn: 0.5021327	total: 18.5s	remaining: 6.92s
# 728:	learn: 0.5021199	total: 18.5s	remaining: 6.89s
# 729:	learn: 0.5021092	total: 18.6s	remaining: 6.86s
# 730:	learn: 0.5021046	total: 18.6s	remaining: 6.83s
# 731:	learn: 0.5020970	total: 18.6s	remaining: 6.81s
# 732:	learn: 0.5020895	total: 18.6s	remaining: 6.78s
# 733:	learn: 0.5020807	total: 18.6s	remaining: 6.75s
# 734:	learn: 0.5020731	total: 18.7s	remaining: 6.73s
# 735:	learn: 0.5020672	total: 18.7s	remaining: 6.7s
# 736:	learn: 0.5020596	total: 18.7s	remaining: 6.67s
# 737:	learn: 0.5020525	total: 18.7s	remaining: 6.65s
# 738:	learn: 0.5020440	total: 18.7s	remaining: 6.62s
# 739:	learn: 0.5020349	total: 18.8s	remaining: 6.6s
# 740:	learn: 0.5020248	total: 18.8s	remaining: 6.57s
# 741:	learn: 0.5020204	total: 18.8s	remaining: 6.55s
# 742:	learn: 0.5020128	total: 18.8s	remaining: 6.52s
# 743:	learn: 0.5020062	total: 18.9s	remaining: 6.49s
# 744:	learn: 0.5019940	total: 18.9s	remaining: 6.47s
# 745:	learn: 0.5019872	total: 18.9s	remaining: 6.44s
# 746:	learn: 0.5019824	total: 18.9s	remaining: 6.41s
# 747:	learn: 0.5019763	total: 19s	remaining: 6.39s
# 748:	learn: 0.5019671	total: 19s	remaining: 6.37s
# 749:	learn: 0.5019637	total: 19s	remaining: 6.34s
# 750:	learn: 0.5019505	total: 19.1s	remaining: 6.32s
# 751:	learn: 0.5019389	total: 19.1s	remaining: 6.3s
# 752:	learn: 0.5019308	total: 19.1s	remaining: 6.27s
# 753:	learn: 0.5019261	total: 19.2s	remaining: 6.25s
# 754:	learn: 0.5019183	total: 19.2s	remaining: 6.23s
# 755:	learn: 0.5019064	total: 19.2s	remaining: 6.2s
# 756:	learn: 0.5018979	total: 19.3s	remaining: 6.18s
# 757:	learn: 0.5018856	total: 19.3s	remaining: 6.16s
# 758:	learn: 0.5018771	total: 19.3s	remaining: 6.14s
# 759:	learn: 0.5018692	total: 19.4s	remaining: 6.12s
# 760:	learn: 0.5018587	total: 19.4s	remaining: 6.09s
# 761:	learn: 0.5018517	total: 19.4s	remaining: 6.07s
# 762:	learn: 0.5018461	total: 19.5s	remaining: 6.04s
# 763:	learn: 0.5018352	total: 19.5s	remaining: 6.02s
# 764:	learn: 0.5018262	total: 19.5s	remaining: 5.99s
# 765:	learn: 0.5018196	total: 19.5s	remaining: 5.97s
# 766:	learn: 0.5018123	total: 19.6s	remaining: 5.95s
# 767:	learn: 0.5018058	total: 19.6s	remaining: 5.92s
# 768:	learn: 0.5017983	total: 19.6s	remaining: 5.89s
# 769:	learn: 0.5017917	total: 19.6s	remaining: 5.87s
# 770:	learn: 0.5017825	total: 19.7s	remaining: 5.84s
# 771:	learn: 0.5017750	total: 19.7s	remaining: 5.82s
# 772:	learn: 0.5017634	total: 19.7s	remaining: 5.79s
# 773:	learn: 0.5017553	total: 19.7s	remaining: 5.77s
# 774:	learn: 0.5017465	total: 19.8s	remaining: 5.74s
# 775:	learn: 0.5017396	total: 19.8s	remaining: 5.71s
# 776:	learn: 0.5017333	total: 19.8s	remaining: 5.69s
# 777:	learn: 0.5017248	total: 19.8s	remaining: 5.66s
# 778:	learn: 0.5017204	total: 19.9s	remaining: 5.64s
# 779:	learn: 0.5017108	total: 19.9s	remaining: 5.61s
# 780:	learn: 0.5017006	total: 19.9s	remaining: 5.58s
# 781:	learn: 0.5016951	total: 19.9s	remaining: 5.55s
# 782:	learn: 0.5016859	total: 19.9s	remaining: 5.53s
# 783:	learn: 0.5016766	total: 20s	remaining: 5.5s
# 784:	learn: 0.5016680	total: 20s	remaining: 5.48s
# 785:	learn: 0.5016613	total: 20s	remaining: 5.45s
# 786:	learn: 0.5016463	total: 20s	remaining: 5.42s
# 787:	learn: 0.5016349	total: 20.1s	remaining: 5.4s
# 788:	learn: 0.5016307	total: 20.1s	remaining: 5.37s
# 789:	learn: 0.5016227	total: 20.1s	remaining: 5.35s
# 790:	learn: 0.5016140	total: 20.1s	remaining: 5.32s
# 791:	learn: 0.5016079	total: 20.2s	remaining: 5.29s
# 792:	learn: 0.5015996	total: 20.2s	remaining: 5.27s
# 793:	learn: 0.5015929	total: 20.2s	remaining: 5.24s
# 794:	learn: 0.5015839	total: 20.2s	remaining: 5.22s
# 795:	learn: 0.5015797	total: 20.3s	remaining: 5.19s
# 796:	learn: 0.5015710	total: 20.3s	remaining: 5.16s
# 797:	learn: 0.5015627	total: 20.3s	remaining: 5.14s
# 798:	learn: 0.5015581	total: 20.3s	remaining: 5.11s
# 799:	learn: 0.5015530	total: 20.3s	remaining: 5.08s
# 800:	learn: 0.5015453	total: 20.4s	remaining: 5.06s
# 801:	learn: 0.5015347	total: 20.4s	remaining: 5.03s
# 802:	learn: 0.5015244	total: 20.4s	remaining: 5.01s
# 803:	learn: 0.5015158	total: 20.4s	remaining: 4.98s
# 804:	learn: 0.5015089	total: 20.5s	remaining: 4.96s
# 805:	learn: 0.5015014	total: 20.5s	remaining: 4.93s
# 806:	learn: 0.5014953	total: 20.5s	remaining: 4.91s
# 807:	learn: 0.5014879	total: 20.5s	remaining: 4.88s
# 808:	learn: 0.5014800	total: 20.6s	remaining: 4.85s
# 809:	learn: 0.5014729	total: 20.6s	remaining: 4.83s
# 810:	learn: 0.5014649	total: 20.6s	remaining: 4.8s
# 811:	learn: 0.5014576	total: 20.6s	remaining: 4.78s
# 812:	learn: 0.5014483	total: 20.7s	remaining: 4.75s
# 813:	learn: 0.5014397	total: 20.7s	remaining: 4.73s
# 814:	learn: 0.5014295	total: 20.7s	remaining: 4.7s
# 815:	learn: 0.5014218	total: 20.7s	remaining: 4.67s
# 816:	learn: 0.5014138	total: 20.8s	remaining: 4.65s
# 817:	learn: 0.5014042	total: 20.8s	remaining: 4.62s
# 818:	learn: 0.5013970	total: 20.8s	remaining: 4.59s
# 819:	learn: 0.5013875	total: 20.8s	remaining: 4.57s
# 820:	learn: 0.5013813	total: 20.8s	remaining: 4.54s
# 821:	learn: 0.5013739	total: 20.9s	remaining: 4.51s
# 822:	learn: 0.5013670	total: 20.9s	remaining: 4.49s
# 823:	learn: 0.5013577	total: 20.9s	remaining: 4.46s
# 824:	learn: 0.5013528	total: 20.9s	remaining: 4.44s
# 825:	learn: 0.5013454	total: 20.9s	remaining: 4.41s
# 826:	learn: 0.5013373	total: 21s	remaining: 4.38s
# 827:	learn: 0.5013254	total: 21s	remaining: 4.36s
# 828:	learn: 0.5013189	total: 21s	remaining: 4.33s
# 829:	learn: 0.5013088	total: 21s	remaining: 4.31s
# 830:	learn: 0.5013009	total: 21.1s	remaining: 4.28s
# 831:	learn: 0.5012891	total: 21.1s	remaining: 4.26s
# 832:	learn: 0.5012805	total: 21.1s	remaining: 4.23s
# 833:	learn: 0.5012719	total: 21.1s	remaining: 4.2s
# 834:	learn: 0.5012652	total: 21.1s	remaining: 4.18s
# 835:	learn: 0.5012557	total: 21.2s	remaining: 4.15s
# 836:	learn: 0.5012454	total: 21.2s	remaining: 4.13s
# 837:	learn: 0.5012379	total: 21.2s	remaining: 4.1s
# 838:	learn: 0.5012310	total: 21.2s	remaining: 4.08s
# 839:	learn: 0.5012260	total: 21.3s	remaining: 4.05s
# 840:	learn: 0.5012196	total: 21.3s	remaining: 4.02s
# 841:	learn: 0.5012129	total: 21.3s	remaining: 4s
# 842:	learn: 0.5012041	total: 21.3s	remaining: 3.97s
# 843:	learn: 0.5011933	total: 21.3s	remaining: 3.94s
# 844:	learn: 0.5011825	total: 21.4s	remaining: 3.92s
# 845:	learn: 0.5011749	total: 21.4s	remaining: 3.89s
# 846:	learn: 0.5011660	total: 21.4s	remaining: 3.86s
# 847:	learn: 0.5011564	total: 21.4s	remaining: 3.84s
# 848:	learn: 0.5011460	total: 21.4s	remaining: 3.81s
# 849:	learn: 0.5011394	total: 21.5s	remaining: 3.79s
# 850:	learn: 0.5011292	total: 21.5s	remaining: 3.76s
# 851:	learn: 0.5011183	total: 21.5s	remaining: 3.73s
# 852:	learn: 0.5011123	total: 21.5s	remaining: 3.71s
# 853:	learn: 0.5011090	total: 21.5s	remaining: 3.68s
# 854:	learn: 0.5011017	total: 21.6s	remaining: 3.66s
# 855:	learn: 0.5010925	total: 21.6s	remaining: 3.63s
# 856:	learn: 0.5010853	total: 21.6s	remaining: 3.6s
# 857:	learn: 0.5010719	total: 21.6s	remaining: 3.58s
# 858:	learn: 0.5010641	total: 21.6s	remaining: 3.55s
# 859:	learn: 0.5010557	total: 21.7s	remaining: 3.53s
# 860:	learn: 0.5010483	total: 21.7s	remaining: 3.5s
# 861:	learn: 0.5010393	total: 21.7s	remaining: 3.48s
# 862:	learn: 0.5010344	total: 21.7s	remaining: 3.45s
# 863:	learn: 0.5010267	total: 21.8s	remaining: 3.43s
# 864:	learn: 0.5010177	total: 21.8s	remaining: 3.4s
# 865:	learn: 0.5010103	total: 21.8s	remaining: 3.38s
# 866:	learn: 0.5010006	total: 21.9s	remaining: 3.35s
# 867:	learn: 0.5009935	total: 21.9s	remaining: 3.33s
# 868:	learn: 0.5009879	total: 21.9s	remaining: 3.3s
# 869:	learn: 0.5009807	total: 21.9s	remaining: 3.27s
# 870:	learn: 0.5009716	total: 21.9s	remaining: 3.25s
# 871:	learn: 0.5009645	total: 22s	remaining: 3.22s
# 872:	learn: 0.5009568	total: 22s	remaining: 3.2s
# 873:	learn: 0.5009495	total: 22s	remaining: 3.17s
# 874:	learn: 0.5009447	total: 22s	remaining: 3.15s
# 875:	learn: 0.5009404	total: 22s	remaining: 3.12s
# 876:	learn: 0.5009355	total: 22.1s	remaining: 3.1s
# 877:	learn: 0.5009256	total: 22.1s	remaining: 3.07s
# 878:	learn: 0.5009187	total: 22.1s	remaining: 3.04s
# 879:	learn: 0.5009145	total: 22.1s	remaining: 3.02s
# 880:	learn: 0.5009090	total: 22.2s	remaining: 2.99s
# 881:	learn: 0.5009011	total: 22.2s	remaining: 2.97s
# 882:	learn: 0.5008916	total: 22.2s	remaining: 2.94s
# 883:	learn: 0.5008820	total: 22.2s	remaining: 2.92s
# 884:	learn: 0.5008740	total: 22.2s	remaining: 2.89s
# 885:	learn: 0.5008645	total: 22.3s	remaining: 2.86s
# 886:	learn: 0.5008570	total: 22.3s	remaining: 2.84s
# 887:	learn: 0.5008505	total: 22.3s	remaining: 2.81s
# 888:	learn: 0.5008469	total: 22.3s	remaining: 2.79s
# 889:	learn: 0.5008436	total: 22.4s	remaining: 2.76s
# 890:	learn: 0.5008370	total: 22.4s	remaining: 2.74s
# 891:	learn: 0.5008316	total: 22.4s	remaining: 2.71s
# 892:	learn: 0.5008222	total: 22.4s	remaining: 2.69s
# 893:	learn: 0.5008126	total: 22.5s	remaining: 2.66s
# 894:	learn: 0.5008044	total: 22.5s	remaining: 2.64s
# 895:	learn: 0.5007949	total: 22.5s	remaining: 2.61s
# 896:	learn: 0.5007890	total: 22.5s	remaining: 2.59s
# 897:	learn: 0.5007808	total: 22.6s	remaining: 2.56s
# 898:	learn: 0.5007728	total: 22.6s	remaining: 2.54s
# 899:	learn: 0.5007654	total: 22.6s	remaining: 2.51s
# 900:	learn: 0.5007604	total: 22.6s	remaining: 2.49s
# 901:	learn: 0.5007566	total: 22.7s	remaining: 2.46s
# 902:	learn: 0.5007502	total: 22.7s	remaining: 2.44s
# 903:	learn: 0.5007406	total: 22.7s	remaining: 2.41s
# 904:	learn: 0.5007315	total: 22.7s	remaining: 2.38s
# 905:	learn: 0.5007248	total: 22.7s	remaining: 2.36s
# 906:	learn: 0.5007165	total: 22.8s	remaining: 2.33s
# 907:	learn: 0.5007020	total: 22.8s	remaining: 2.31s
# 908:	learn: 0.5006940	total: 22.8s	remaining: 2.28s
# 909:	learn: 0.5006803	total: 22.8s	remaining: 2.26s
# 910:	learn: 0.5006745	total: 22.9s	remaining: 2.23s
# 911:	learn: 0.5006626	total: 22.9s	remaining: 2.21s
# 912:	learn: 0.5006548	total: 22.9s	remaining: 2.18s
# 913:	learn: 0.5006480	total: 22.9s	remaining: 2.16s
# 914:	learn: 0.5006400	total: 22.9s	remaining: 2.13s
# 915:	learn: 0.5006336	total: 23s	remaining: 2.11s
# 916:	learn: 0.5006250	total: 23s	remaining: 2.08s
# 917:	learn: 0.5006178	total: 23s	remaining: 2.06s
# 918:	learn: 0.5006062	total: 23.1s	remaining: 2.03s
# 919:	learn: 0.5005998	total: 23.1s	remaining: 2s
# 920:	learn: 0.5005925	total: 23.1s	remaining: 1.98s
# 921:	learn: 0.5005865	total: 23.1s	remaining: 1.95s
# 922:	learn: 0.5005816	total: 23.1s	remaining: 1.93s
# 923:	learn: 0.5005753	total: 23.1s	remaining: 1.9s
# 924:	learn: 0.5005695	total: 23.2s	remaining: 1.88s
# 925:	learn: 0.5005570	total: 23.2s	remaining: 1.85s
# 926:	learn: 0.5005487	total: 23.2s	remaining: 1.83s
# 927:	learn: 0.5005429	total: 23.2s	remaining: 1.8s
# 928:	learn: 0.5005359	total: 23.2s	remaining: 1.78s
# 929:	learn: 0.5005262	total: 23.3s	remaining: 1.75s
# 930:	learn: 0.5005222	total: 23.3s	remaining: 1.73s
# 931:	learn: 0.5005145	total: 23.3s	remaining: 1.7s
# 932:	learn: 0.5005070	total: 23.3s	remaining: 1.67s
# 933:	learn: 0.5004966	total: 23.3s	remaining: 1.65s
# 934:	learn: 0.5004864	total: 23.4s	remaining: 1.62s
# 935:	learn: 0.5004788	total: 23.4s	remaining: 1.6s
# 936:	learn: 0.5004701	total: 23.4s	remaining: 1.57s
# 937:	learn: 0.5004590	total: 23.4s	remaining: 1.55s
# 938:	learn: 0.5004520	total: 23.5s	remaining: 1.52s
# 939:	learn: 0.5004451	total: 23.5s	remaining: 1.5s
# 940:	learn: 0.5004393	total: 23.5s	remaining: 1.47s
# 941:	learn: 0.5004315	total: 23.5s	remaining: 1.45s
# 942:	learn: 0.5004255	total: 23.5s	remaining: 1.42s
# 943:	learn: 0.5004160	total: 23.6s	remaining: 1.4s
# 944:	learn: 0.5004088	total: 23.6s	remaining: 1.37s
# 945:	learn: 0.5004039	total: 23.6s	remaining: 1.35s
# 946:	learn: 0.5003939	total: 23.6s	remaining: 1.32s
# 947:	learn: 0.5003885	total: 23.6s	remaining: 1.3s
# 948:	learn: 0.5003763	total: 23.7s	remaining: 1.27s
# 949:	learn: 0.5003684	total: 23.7s	remaining: 1.25s
# 950:	learn: 0.5003618	total: 23.7s	remaining: 1.22s
# 951:	learn: 0.5003512	total: 23.8s	remaining: 1.2s
# 952:	learn: 0.5003455	total: 23.8s	remaining: 1.17s
# 953:	learn: 0.5003324	total: 23.8s	remaining: 1.15s
# 954:	learn: 0.5003236	total: 23.8s	remaining: 1.12s
# 955:	learn: 0.5003131	total: 23.8s	remaining: 1.1s
# 956:	learn: 0.5003053	total: 23.9s	remaining: 1.07s
# 957:	learn: 0.5002997	total: 23.9s	remaining: 1.05s
# 958:	learn: 0.5002905	total: 23.9s	remaining: 1.02s
# 959:	learn: 0.5002844	total: 23.9s	remaining: 997ms
# 960:	learn: 0.5002740	total: 24s	remaining: 972ms
# 961:	learn: 0.5002650	total: 24s	remaining: 947ms
# 962:	learn: 0.5002529	total: 24s	remaining: 922ms
# 963:	learn: 0.5002400	total: 24s	remaining: 897ms
# 964:	learn: 0.5002333	total: 24.1s	remaining: 872ms
# 965:	learn: 0.5002254	total: 24.1s	remaining: 848ms
# 966:	learn: 0.5002187	total: 24.1s	remaining: 823ms
# 967:	learn: 0.5002105	total: 24.1s	remaining: 798ms
# 968:	learn: 0.5002020	total: 24.2s	remaining: 773ms
# 969:	learn: 0.5001922	total: 24.2s	remaining: 748ms
# 970:	learn: 0.5001841	total: 24.2s	remaining: 723ms
# 971:	learn: 0.5001742	total: 24.2s	remaining: 698ms
# 972:	learn: 0.5001645	total: 24.3s	remaining: 673ms
# 973:	learn: 0.5001585	total: 24.3s	remaining: 648ms
# 974:	learn: 0.5001515	total: 24.3s	remaining: 623ms
# 975:	learn: 0.5001422	total: 24.3s	remaining: 598ms
# 976:	learn: 0.5001355	total: 24.4s	remaining: 573ms
# 977:	learn: 0.5001262	total: 24.4s	remaining: 548ms
# 978:	learn: 0.5001177	total: 24.4s	remaining: 523ms
# 979:	learn: 0.5001100	total: 24.4s	remaining: 498ms
# 980:	learn: 0.5001050	total: 24.5s	remaining: 474ms
# 981:	learn: 0.5000991	total: 24.5s	remaining: 449ms
# 982:	learn: 0.5000897	total: 24.5s	remaining: 424ms
# 983:	learn: 0.5000834	total: 24.5s	remaining: 399ms
# 984:	learn: 0.5000727	total: 24.6s	remaining: 374ms
# 985:	learn: 0.5000663	total: 24.6s	remaining: 349ms
# 986:	learn: 0.5000597	total: 24.6s	remaining: 324ms
# 987:	learn: 0.5000501	total: 24.6s	remaining: 299ms
# 988:	learn: 0.5000444	total: 24.7s	remaining: 274ms
# 989:	learn: 0.5000346	total: 24.7s	remaining: 249ms
# 990:	learn: 0.5000249	total: 24.7s	remaining: 224ms
# 991:	learn: 0.5000174	total: 24.7s	remaining: 199ms
# 992:	learn: 0.5000128	total: 24.8s	remaining: 175ms
# 993:	learn: 0.5000104	total: 24.8s	remaining: 150ms
# 994:	learn: 0.5000029	total: 24.8s	remaining: 125ms
# 995:	learn: 0.4999975	total: 24.8s	remaining: 99.7ms
# 996:	learn: 0.4999898	total: 24.9s	remaining: 74.8ms
# 997:	learn: 0.4999818	total: 24.9s	remaining: 49.9ms
# 998:	learn: 0.4999743	total: 24.9s	remaining: 24.9ms
# 999:	learn: 0.4999657	total: 24.9s	remaining: 0us

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score, roc_curve
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import seaborn as sns

# Seaborn 스타일 초기화
sns.set_style("white")

# 검증 데이터
X_val = val.drop(columns=['churn'])
y_val = val['churn']

# -----------------------------------------------------------
# 검증 데이터 (Validation) 평가
# -----------------------------------------------------------
# 검증 데이터(val) 예측
val_predictions = cat_model.predict(X_val)

# 정확도 확인
val_accuracy = accuracy_score(y_val, val_predictions)
print(f"Validation Accuracy: {val_accuracy:.2f}")

# Classification Report
print("\nClassification Report (Validation):")
print(classification_report(y_val, val_predictions))

# Confusion Matrix
print("\nConfusion Matrix (Validation):")
conf_matrix = confusion_matrix(y_val, val_predictions)
print(conf_matrix)
disp_val = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=cat_model.classes_)
disp_val.plot(cmap="Blues")
plt.title("Validation Confusion Matrix")
plt.show()

# -----------------------------------------------------------
# AUC-ROC 계산 및 시각화
# -----------------------------------------------------------
val_probabilities = cat_model.predict_proba(X_val)[:, 1]  # 클래스 1에 대한 확률
val_auc = roc_auc_score(y_val, val_probabilities)
print(f"Validation AUC-ROC: {val_auc:.2f}")

# ROC Curve 계산
fpr_val, tpr_val, thresholds_val = roc_curve(y_val, val_probabilities)

# ROC Curve 시각화
plt.figure()
plt.plot(fpr_val, tpr_val, label=f"Validation ROC Curve (AUC = {val_auc:.2f})", color='blue')
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label="Random Guess")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Validation ROC Curve")
plt.legend()
plt.grid(alpha=0.3)
plt.show()
# Out:
# Validation Accuracy: 0.81
#
# Classification Report (Validation):
#               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.90   1941863
#            1       0.02      0.68      0.05     13252
#
#     accuracy                           0.81   1955115
#    macro avg       0.51      0.75      0.47   1955115
# weighted avg       0.99      0.81      0.89   1955115
#
#
# Confusion Matrix (Validation):
# [[1577534  364329]
#  [   4228    9024]]
# Validation AUC-ROC: 0.82

# %%
import pandas as pd
import matplotlib.pyplot as plt

# CatBoost Feature Importance 추출
feature_importance = cat_model.get_feature_importance()

# DataFrame 변환 및 정렬
feature_importance_df = pd.DataFrame({
    'Feature': X_train.columns,
    'Importance': feature_importance
}).sort_values(by='Importance', ascending=False)

# Feature Importance 시각화
plt.figure(figsize=(12, 8))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'], color='skyblue')
plt.xlabel("Feature Importance")
plt.ylabel("Features")
plt.title("CatBoost Feature Importance")
plt.gca().invert_yaxis()
plt.show()

print("✅ Feature Importance")
for rank, feature in enumerate(feature_importance_df['Feature'], 1):
    print(f"{rank}. {feature}")
# Out:
# ✅ Feature Importance
# 1. VOC_STOP_CANCEL_MONTH1_YN
# 2. MONTHS_REMAINING
# 3. CH_LAST_DAYS_BF_GRP
# 4. TOTAL_USED_DAYS
# 5. AGE_GRP10
# 6. TV_I_CNT
# 7. CH_HH_AVG_MONTH1

# %% [markdown]
# ---

# %% [markdown]
# ### 가중치로 진행
# 1. 로지스틱
# 2. LGBM

# %% [markdown]
# #### 1. LR 가중치

# %%
# 2월 ~ 9월 train
# 6월 val
# 11월 test
train = df[df['p_mt'].isin([2,3,4,5,7,8,9])]
val = df[df['p_mt'] == 6]
test = df[df['p_mt'] == 11]

# %%
train
# Out:
#                                                                  sha2_hash  \
# 0         0000113b86db7c509bbe74d609529031b03b7c033dbdfbd8b7fcecbf92bc8600
# 1         0000113b86db7c509bbe74d609529031b03b7c033dbdfbd8b7fcecbf92bc8600
# 2         0000113b86db7c509bbe74d609529031b03b7c033dbdfbd8b7fcecbf92bc8600
# 3         0000113b86db7c509bbe74d609529031b03b7c033dbdfbd8b7fcecbf92bc8600
# 5         0000113b86db7c509bbe74d609529031b03b7c033dbdfbd8b7fcecbf92bc8600
# ...                                                                    ...
# 21483370  fffffa7eda8144ce27e65690933ae8994e6962fefd24c982990467add99d61a7
# 21483371  fffffa7eda8144ce27e65690933ae8994e6962fefd24c982990467add99d61a7
# 21483373  fffffa7eda8144ce27e65690933ae8994e6962fefd24c982990467add99d61a7
# 21483374  fffffa7eda8144ce27e65690933ae8994e6962fefd24c982990467add99d61a7
# 21483375  fffffa7eda8144ce27e65690933ae8994e6962fefd24c982990467add99d61a7
#
#           TOTAL_USED_DAYS  TV_I_CNT CH_LAST_DAYS_BF_GRP  \
# 0                     733      3.00              3개월내없음
# 1                     764      3.00                일주일내
# 2                     794      3.00                3주일전
# 3                     825      3.00                4주일전
# 5                     886      3.00                일주일내
# ...                   ...       ...                 ...
# 21483370             2215      1.00                일주일내
# 21483371             2246      1.00                일주일내
# 21483373             2307      1.00                일주일내
# 21483374             2338      1.00                일주일내
# 21483375             2368      1.00                일주일내
#
#          VOC_STOP_CANCEL_MONTH1_YN AGE_GRP10  CH_HH_AVG_MONTH1  \
# 0                                N       60대              0.00
# 1                                N       60대              6.72
# 2                                N       60대              9.86
# 3                                N       60대              5.95
# 5                                N       60대              2.93
# ...                            ...       ...               ...
# 21483370                         N       50대              2.42
# 21483371                         N       50대              3.67
# 21483373                         N       50대              4.10
# 21483374                         N       50대              2.03
# 21483375                         N       50대              2.91
#
#           MONTHS_REMAINING  p_mt churn
# 0                       13     2     N
# 1                       12     3     N
# 2                       11     4     N
# 3                       10     5     N
# 5                        8     7     N
# ...                    ...   ...   ...
# 21483370               -36     4     N
# 21483371               -37     5     N
# 21483373               -39     7     N
# 21483374               -40     8     N
# 21483375               -41     9     N
#
# [13691921 rows x 10 columns]

# %%
train = train.drop(columns=['sha2_hash','p_mt'])
val = val.drop(columns=['sha2_hash','p_mt'])
test = test.drop(columns=['sha2_hash','p_mt'])

# %%
# 레이블 인코딩 진행!

from sklearn.preprocessing import LabelEncoder

categorical_cols = train.select_dtypes(include=['object']).columns

# 레이블 인코딩 수행
label_encoders = {}
for col in categorical_cols:
    le = LabelEncoder()
    train[col] = le.fit_transform(train[col])
    val[col] = le.transform(val[col])
    test[col] = le.transform(test[col])
    label_encoders[col] = le

print("레이블 인코딩 끝")
# Out:
# 레이블 인코딩 끝

# %%
display(train)
display(val)
display(test)
# Out:
#           TOTAL_USED_DAYS  TV_I_CNT  CH_LAST_DAYS_BF_GRP  \
# 0                     733      3.00                    1
# 1                     764      3.00                    4
# 2                     794      3.00                    2
# 3                     825      3.00                    3
# 5                     886      3.00                    4
# ...                   ...       ...                  ...
# 21483370             2215      1.00                    4
# 21483371             2246      1.00                    4
# 21483373             2307      1.00                    4
# 21483374             2338      1.00                    4
# 21483375             2368      1.00                    4
#
#           VOC_STOP_CANCEL_MONTH1_YN  AGE_GRP10  CH_HH_AVG_MONTH1  \
# 0                                 0          5              0.00
# 1                                 0          5              6.72
# 2                                 0          5              9.86
# 3                                 0          5              5.95
# 5                                 0          5              2.93
# ...                             ...        ...               ...
# 21483370                          0          4              2.42
# 21483371                          0          4              3.67
# 21483373                          0          4              4.10
# 21483374                          0          4              2.03
# 21483375                          0          4              2.91
#
#           MONTHS_REMAINING  churn
# 0                       13      0
# 1                       12      0
# 2                       11      0
# 3                       10      0
# 5                        8      0
# ...                    ...    ...
# 21483370               -36      0
# 21483371               -37      0
# 21483373               -39      0
# 21483374               -40      0
# 21483375               -41      0
#
# [13691921 rows x 8 columns]
#           TOTAL_USED_DAYS  TV_I_CNT  CH_LAST_DAYS_BF_GRP  \
# 4                     855      3.00                    4
# 15                   4249      2.00                    4
# 26                   2488      6.00                    4
# 37                   1836      3.00                    4
# 48                   3826      4.00                    4
# ...                   ...       ...                  ...
# 21483328             3446      2.00                    0
# 21483339             2128      3.00                    4
# 21483350             3805      2.00                    4
# 21483361             1399      2.00                    4
# 21483372             2276      1.00                    4
#
#           VOC_STOP_CANCEL_MONTH1_YN  AGE_GRP10  CH_HH_AVG_MONTH1  \
# 4                                 0          5              4.03
# 15                                0          4             18.08
# 26                                0          5              1.09
# 37                                0          5              1.32
# 48                                0          4              1.27
# ...                             ...        ...               ...
# 21483328                          0          4              1.72
# 21483339                          0          3              2.12
# 21483350                          0          2              0.73
# 21483361                          0          4              4.37
# 21483372                          0          4              3.14
#
#           MONTHS_REMAINING  churn
# 4                        9      0
# 15                      12      0
# 26                      25      0
# 37                      -5      0
# 48                     -46      0
# ...                    ...    ...
# 21483328               -43      0
# 21483339               -34      0
# 21483350              -104      0
# 21483361                24      0
# 21483372               -38      0
#
# [1955115 rows x 8 columns]
#           TOTAL_USED_DAYS  TV_I_CNT  CH_LAST_DAYS_BF_GRP  \
# 9                    1008      3.00                    4
# 20                   4402      2.00                    4
# 31                   2641      6.00                    4
# 42                   1989      3.00                    4
# 53                   3979      4.00                    4
# ...                   ...       ...                  ...
# 21483333             3599      2.00                    1
# 21483344             2281      3.00                    4
# 21483355             3958      2.00                    4
# 21483366             1552      2.00                    4
# 21483377             2429      1.00                    1
#
#           VOC_STOP_CANCEL_MONTH1_YN  AGE_GRP10  CH_HH_AVG_MONTH1  \
# 9                                 0          5              6.23
# 20                                0          4             15.37
# 31                                0          5              1.47
# 42                                0          5              2.16
# 53                                0          4              1.64
# ...                             ...        ...               ...
# 21483333                          0          4              0.00
# 21483344                          0          3              1.81
# 21483355                          0          2              1.69
# 21483366                          0          4              3.39
# 21483377                          0          4              0.00
#
#           MONTHS_REMAINING  churn
# 9                       33      0
# 20                       7      0
# 31                      20      0
# 42                     -10      0
# 53                     -51      0
# ...                    ...    ...
# 21483333               -48      0
# 21483344               -39      0
# 21483355              -109      0
# 21483366                19      0
# 21483377               -43      0
#
# [1945592 rows x 8 columns]

# %%
from sklearn.preprocessing import MinMaxScaler, RobustScaler

# 내가 정한 robust 스케일링 컬럼들
robust_columns = ['TOTAL_USED_DAYS', 'CH_HH_AVG_MONTH1','MONTHS_REMAINING']  # RobustScaler를 적용할 컬럼
minmax_columns = [col for col in train.columns if col not in robust_columns + ['churn']]  # 나머지 컬럼

# 스케일러 생성
robust_scaler = RobustScaler()
minmax_scaler = MinMaxScaler()

# RobustScaler 적용
train[robust_columns] = robust_scaler.fit_transform(train[robust_columns])
val[robust_columns] = robust_scaler.transform(val[robust_columns])
test[robust_columns] = robust_scaler.transform(test[robust_columns])

# MinMaxScaler 적용
train[minmax_columns] = minmax_scaler.fit_transform(train[minmax_columns])
val[minmax_columns] = minmax_scaler.transform(val[minmax_columns])
test[minmax_columns] = minmax_scaler.transform(test[minmax_columns])

# 결과 확인
print("robust, minmax 끝")
# Out:
# robust, minmax 끝

# %%
# 로지스틱 회귀 모델 진행

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

X_train = train.drop(columns=['churn'])
y_train = train['churn']

# 로지스틱 회귀 모델 생성
model = LogisticRegression(class_weight='balanced', solver='liblinear', random_state=42)

# 모델 학습
model.fit(X_train, y_train)
# Out:
# LogisticRegression(class_weight='balanced', random_state=42, solver='liblinear')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score, roc_curve
from sklearn.metrics import ConfusionMatrixDisplay  # ConfusionMatrixDisplay 임포트
import matplotlib.pyplot as plt
import seaborn as sns

# Seaborn 스타일 초기화
sns.set_style("white")

# 검증 데이터
X_val = val.drop(columns=['churn'])
y_val = val['churn']

# -----------------------------------------------------------
# 검증 데이터 (Validation) 평가
# -----------------------------------------------------------
# 검증 데이터(val) 예측
val_predictions = model.predict(X_val)

# 정확도 확인
val_accuracy = accuracy_score(y_val, val_predictions)
print(f"Validation Accuracy: {val_accuracy:.2f}")

# Classification Report
print("\nClassification Report (Validation):")
print(classification_report(y_val, val_predictions))

# Confusion Matrix
print("\nConfusion Matrix (Validation):")
print(confusion_matrix(y_val, val_predictions))
disp_val = ConfusionMatrixDisplay(confusion_matrix=confusion_matrix(y_val, val_predictions), display_labels=model.classes_)

# Confusion Matrix
plt.figure()
disp_val.plot(cmap="Blues", ax=plt.gca())
plt.grid(False)
plt.title("Validation Confusion Matrix")
plt.show()

# AUC-ROC 계산 및 시각화
val_probabilities = model.predict_proba(X_val)[:, 1]  # 클래스 1에 대한 확률
val_auc = roc_auc_score(y_val, val_probabilities)
print(f"Validation AUC-ROC: {val_auc:.2f}")

# ROC Curve 시각화
fpr_val, tpr_val, thresholds_val = roc_curve(y_val, val_probabilities)
plt.figure()
plt.plot(fpr_val, tpr_val, label=f"Validation ROC Curve (AUC = {val_auc:.2f})")
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label="Random Guess")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Validation ROC Curve")
plt.legend()
plt.grid(False)
plt.show()
# Out:
# Validation Accuracy: 0.79
#
# Classification Report (Validation):
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88   1941863
#            1       0.02      0.63      0.04     13252
#
#     accuracy                           0.79   1955115
#    macro avg       0.51      0.71      0.46   1955115
# weighted avg       0.99      0.79      0.88   1955115
#
#
# Confusion Matrix (Validation):
# [[1535583  406280]
#  [   4934    8318]]
# Validation AUC-ROC: 0.77

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

feature_importance = np.abs(model.coef_[0])

feature_importance_df = pd.DataFrame({
    'Feature': X_train.columns,
    'Importance': feature_importance
}).sort_values(by='Importance', ascending=False)

plt.figure(figsize=(10, 6))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'], color='skyblue')
plt.xlabel("Feature Importance")
plt.ylabel("Features")
plt.title("Logistic Regression Feature Importance")
plt.gca().invert_yaxis()
plt.show()

print("✅ Feature Importance")
for rank, feature in enumerate(feature_importance_df['Feature'], 1):
    print(f"{rank}. {feature}")
# Out:
# ✅ Feature Importance
# 1. VOC_STOP_CANCEL_MONTH1_YN
# 2. CH_LAST_DAYS_BF_GRP
# 3. AGE_GRP10
# 4. TOTAL_USED_DAYS
# 5. MONTHS_REMAINING
# 6. TV_I_CNT
# 7. CH_HH_AVG_MONTH1

# %% [markdown]
# ---

# %% [markdown]
# #### 2. LGBM 가중치

# %%
from lightgbm import LGBMClassifier

# 독립 변수 & 종속 변수 설정
X_train = train.drop(columns=['churn'])  # 독립 변수
y_train = train['churn']  # 종속 변수

# LightGBM 모델 생성
lgbm_model = LGBMClassifier(
    n_estimators=100,
    max_depth=-1,
    learning_rate=0.1,
    class_weight='balanced',  # 클래스 가중치 적용
    random_state=42 
)

# 모델 학습
lgbm_model.fit(X_train, y_train)
# Out:
# LGBMClassifier(class_weight='balanced', random_state=42)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score, roc_curve
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import seaborn as sns

# Seaborn 스타일 초기화
sns.set_style("white")

# 검증 데이터
X_val = val.drop(columns=['churn'])
y_val = val['churn']

# -----------------------------------------------------------
# 검증 데이터 (Validation) 평가
# -----------------------------------------------------------
# 검증 데이터(val) 예측
val_predictions = lgbm_model.predict(X_val)

# 정확도 확인
val_accuracy = accuracy_score(y_val, val_predictions)
print(f"Validation Accuracy: {val_accuracy:.2f}")

# Classification Report
print("\nClassification Report (Validation):")
print(classification_report(y_val, val_predictions))

# Confusion Matrix
print("\nConfusion Matrix (Validation):")
conf_matrix = confusion_matrix(y_val, val_predictions)
print(conf_matrix)
disp_val = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=lgbm_model.classes_)
disp_val.plot(cmap="Blues")
plt.title("Validation Confusion Matrix")
plt.show()

# -----------------------------------------------------------
# AUC-ROC 계산 및 시각화
# -----------------------------------------------------------
val_probabilities = lgbm_model.predict_proba(X_val)[:, 1]  # 클래스 1에 대한 확률
val_auc = roc_auc_score(y_val, val_probabilities)
print(f"Validation AUC-ROC: {val_auc:.2f}")

# ROC Curve 계산
fpr_val, tpr_val, thresholds_val = roc_curve(y_val, val_probabilities)

# ROC Curve 시각화
plt.figure()
plt.plot(fpr_val, tpr_val, label=f"Validation ROC Curve (AUC = {val_auc:.2f})", color='blue')
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label="Random Guess")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Validation ROC Curve")
plt.legend()
plt.grid(alpha=0.3)
plt.show()
# Out:
# Validation Accuracy: 0.81
#
# Classification Report (Validation):
#               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.89   1941863
#            1       0.02      0.68      0.05     13252
#
#     accuracy                           0.81   1955115
#    macro avg       0.51      0.75      0.47   1955115
# weighted avg       0.99      0.81      0.89   1955115
#
#
# Confusion Matrix (Validation):
# [[1574463  367400]
#  [   4190    9062]]
# Validation AUC-ROC: 0.82

# %%
import pandas as pd
import matplotlib.pyplot as plt

# LightGBM Feature Importance 추출
feature_importance = lgbm_model.feature_importances_

# DataFrame 변환 및 정렬
feature_importance_df = pd.DataFrame({
    'Feature': X_train.columns,
    'Importance': feature_importance
}).sort_values(by='Importance', ascending=False)

# Feature Importance 시각화
plt.figure(figsize=(12, 8))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'], color='skyblue')
plt.xlabel("Feature Importance")
plt.ylabel("Features")
plt.title("LightGBM Feature Importance")
plt.gca().invert_yaxis()
plt.show()

print("✅ Feature Importance")
for rank, feature in enumerate(feature_importance_df['Feature'], 1):
    print(f"{rank}. {feature}")
# Out:
# ✅ Feature Importance
# 1. MONTHS_REMAINING
# 2. TOTAL_USED_DAYS
# 3. CH_HH_AVG_MONTH1
# 4. TV_I_CNT
# 5. AGE_GRP10
# 6. CH_LAST_DAYS_BF_GRP
# 7. VOC_STOP_CANCEL_MONTH1_YN

# %% [markdown]
# ---

# %% [markdown]
# 01_14_LGHV_Modeling_afterFE2.ipynb 파일에서 했던 컬럼들로 모델링하는 편이 좀 더 나아보인다.
